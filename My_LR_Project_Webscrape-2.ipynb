# %%
from bs4 import BeautifulSoup
import requests

# %%
def get_mpaa_url(offset_nums):
    main_url = 'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset={}'
    url_list = []
    for num in offset_nums:
        mpaa_url = main_url.format(num)
        url_list.append(mpaa_url)
    return url_list
offset_nums = [600,800,1000,1200,1400]
main_url_list = get_mpaa_url(offset_nums)
main_url_list
# Out:
# ['https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset=600',
#  'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset=800',
#  'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset=1000',
#  'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset=1200',
#  'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset=1400']

# %%
from itertools import chain
import time
full_link = []
for mpaa_url in main_url_list:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    mpaa_response = requests.get(mpaa_url,headers=user_agent)
    mpaa_page = mpaa_response.text
    mpaa_soup = BeautifulSoup(mpaa_page, "lxml")
    mpaa_table = mpaa_soup.find('table')
    rows=[]
    for full_row in mpaa_table.find_all('tr'):
        rows.append(full_row)
    complete_link=[]
    for row in rows[1:201]:
        items = row.find_all('td')
        items_link = items[0].find('a')
        link = items_link['href']
        link = link.split('?')
        link = link[0]
        complete_link.append(link)
        time.sleep(2)
    full_link.append(complete_link)
full_link = list(chain.from_iterable(full_link))
print(full_link)
print(len(full_link))
# Out:
# ['/title/tt0250720/', '/title/tt0090142/', '/title/tt2555736/', '/title/tt0084827/', '/title/tt0108037/', '/title/tt0092494/', '/title/tt0418647/', '/title/tt0122459/', '/title/tt0317132/', '/title/tt0094606/', '/title/tt0132477/', '/title/tt0091653/', '/title/tt0106226/', '/title/tt0074174/', '/title/tt0106613/', '/title/tt0075029/', '/title/tt0078723/', '/title/tt0095800/', '/title/tt0426931/', '/title/tt0433383/', '/title/tt0076141/', '/title/tt1430626/', '/title/tt0087078/', '/title/tt0119303/', '/title/tt0093779/', '/title/tt0110093/', '/title/tt7961060/', '/title/tt0110442/', '/title/tt0109287/', '/title/tt0077869/', '/title/tt0078950/', '/title/tt0117608/', '/title/tt0078841/', '/title/tt2247476/', '/title/tt0113114/', '/title/tt0080801/', '/title/tt0123987/', '/title/tt7424200/', '/title/tt0093148/', '/title/tt0086005/', '/title/tt0086491/', '/title/tt0120185/', '/title/tt0361467/', '/title/tt0406375/', '/title/tt1415283/', '/title/tt0103596/', '/title/tt0116683/', '/title/tt0110123/', '/title/tt2515086/', '/title/tt0088172/', '/title/tt0087597/', '/title/tt0091217/', '/title/tt0077699/', '/title/tt0085678/', '/title/tt0305396/', '/title/tt0455499/', '/title/tt3486626/', '/title/tt0084865/', '/title/tt0095107/', '/title/tt0337697/', '/title/tt0429589/', '/title/tt0274166/', '/title/tt0087032/', '/title/tt0093756/', '/title/tt0268995/', '/title/tt0071877/', '/title/tt0118665/', '/title/tt0050212/', '/title/tt0087892/', '/title/tt5697572/', '/title/tt0083530/', '/title/tt0080948/', '/title/tt0080745/', '/title/tt0125454/', '/title/tt0079219/', '/title/tt0093693/', '/title/tt0092605/', '/title/tt0116493/', '/title/tt0116311/', '/title/tt0165982/', '/title/tt1478839/', '/title/tt0110099/', '/title/tt0110066/', '/title/tt0087951/', '/title/tt0082763/', '/title/tt0104454/', '/title/tt0080678/', '/title/tt0131704/', '/title/tt0076843/', '/title/tt1216492/', '/title/tt0093260/', '/title/tt0117887/', '/title/tt0108101/', '/title/tt1414382/', '/title/tt0086066/', '/title/tt0231402/', '/title/tt0479500/', '/title/tt0095188/', '/title/tt0110612/', '/title/tt2215719/', '/title/tt0775552/', '/title/tt0116329/', '/title/tt1213012/', '/title/tt0104040/', '/title/tt0099512/', '/title/tt0102316/', '/title/tt0077745/', '/title/tt0057076/', '/title/tt0166396/', '/title/tt0099654/', '/title/tt2261287/', '/title/tt0090098/', '/title/tt0114048/', '/title/tt0073317/', '/title/tt1273678/', '/title/tt0080472/', '/title/tt0497116/', '/title/tt0106223/', '/title/tt0327437/', '/title/tt0112302/', '/title/tt0089961/', '/title/tt0119215/', '/title/tt0088128/', '/title/tt0086494/', '/title/tt0358349/', '/title/tt0102603/', '/title/tt0092974/', '/title/tt0106387/', '/title/tt0246002/', '/title/tt0107943/', '/title/tt1067774/', '/title/tt0129167/', '/title/tt0118570/', '/title/tt0116000/', '/title/tt0327679/', '/title/tt0108002/', '/title/tt8385474/', '/title/tt0064757/', '/title/tt0279889/', '/title/tt0077369/', '/title/tt0081777/', '/title/tt0120913/', '/title/tt0102729/', '/title/tt0118755/', '/title/tt0081207/', '/title/tt1016075/', '/title/tt0092965/', '/title/tt0116191/', '/title/tt0079638/', '/title/tt0097142/', '/title/tt4131800/', '/title/tt0110877/', '/title/tt0088146/', '/title/tt0077278/', '/title/tt0096101/', '/title/tt0353774/', '/title/tt1407061/', '/title/tt0087835/', '/title/tt0768212/', '/title/tt0099615/', '/title/tt0092105/', '/title/tt0119718/', '/title/tt0088001/', '/title/tt1305591/', '/title/tt0088814/', '/title/tt4532038/', '/title/tt0106598/', '/title/tt0454776/', '/title/tt0105481/', '/title/tt0086197/', '/title/tt0109067/', '/title/tt0110157/', '/title/tt0432283/', '/title/tt0434215/', '/title/tt0318155/', '/title/tt0071807/', '/title/tt1100119/', '/title/tt0108255/', '/title/tt4824308/', '/title/tt6003368/', '/title/tt0076245/', '/title/tt0099726/', '/title/tt0084296/', '/title/tt0085334/', '/title/tt0071577/', '/title/tt0088286/', '/title/tt0093175/', '/title/tt0077531/', '/title/tt0078239/', '/title/tt0082558/', '/title/t ...
# 1000

# %%
import re
import numpy as np
import time
def get_movie_dict(link):
    try:
        base_url = 'https://www.boxofficemojo.com' 
        url = base_url + link
        user_agent = {'User-agent': 'Mozilla/5.0'}
    
        #Request HTML and parse
        response = requests.get(url,headers=user_agent)
        page = response.text
        soup = BeautifulSoup(page, "lxml")
    
        crew_url = url + 'credits'
        crew_response = requests.get(crew_url,headers=user_agent)
        crew_page = crew_response.text
        crew_soup = BeautifulSoup(crew_page, "lxml")
      
        rankings_url = url +'rankings'
        rankings_response = requests.get(rankings_url,headers=user_agent)
        rankings_page = rankings_response.text
        rankings_soup = BeautifulSoup(rankings_page, "lxml")
  
        headers= ['title','MPAA_rate', 'domestic_gross_pay', 'worldwide_gross_pay' ,'budget' , 'lifetime_ranking', 'running_time',
              'distributor','genre','top_director','top_actor']
    
        #Get Title
        global the_title
        old_title = soup.find('title').text.split('Box')[0]
        if old_title[-2] == '-':
            old_title = old_title[:-2]
            the_title = old_title
    
        #Get MPAA rate
        try:
            rate_string = soup.find(text=re.compile('MPAA'))
            rate = rate_string.findNext()
            rate = rate.text
        except:
            rate = 'PG'
    
        #Get Gross Domestic Pay
        try:
            gross_domestic_pay = soup.find('div',class_='mojo-performance-summary-table').find_all('span', class_='money')[0].text
            gross_domestic_pay = gross_domestic_pay.split('$')[1]
            gross_domestic_pay = gross_domestic_pay.replace(',','')
            gross_domestic_pay = int(gross_domestic_pay)
        except:
            gross_domestic_pay = np.nan
        
        #Find Gross Pay Worldwide 
        try:
            gross_worldwide_pay = soup.find('div', class_='mojo-performance-summary-table').find_all('span',class_='money')[2].text
            gross_worldwide_pay = gross_worldwide_pay.split('$')[1]
            gross_worldwide_pay = gross_worldwide_pay.replace(',','')
            gross_worldwide_pay = int(gross_worldwide_pay)
        except:
            gross_worldwide_pay = np.nan
        
        #Get Budget
        try:
            budget_string = soup.find(text=re.compile('Budget'))
            budget = budget_string.findNext()
            budget = budget.text
            budget = budget.split('$')[1]
            budget = budget.replace(',','')
            budget = int(budget)
        except:
            budget = np.nan
    
        #Top Lifetime Ranking by MPAA Rating
        try:
            rankings = rankings_soup.find(text=re.compile('Top Lifetime Grosses by MPAA Rating'))
            rankings = rankings.findNext().text
            rankings = int(rankings)
        except:
            rankings = np.nan
        
        #Get Running Time
        try:
            rt_string = (soup.find(text=re.compile('Running Time')))
            rt = rt_string.findNext().text
            rt = rt.split()
            minutes = int(rt[0])*60 + int(rt[2])
        except:
            minutes = np.nan

        #Get Distributor
        try:
            dist_string = soup.find('div',class_="mojo-summary-values").find_all('span')
            dist = dist_string[1].text
            dist = dist.replace("See full company information", '').replace('\n',"")
        except:
            dist = np.nan
        
        #Get Genre
        try:
            genre_string= soup.find(text=re.compile('Genres'))
            genre_string = genre_string.findNext()
            genre_string = genre_string.text.replace('\n',' ')
            genre_string.split()
        except:
            genre_string = np.nan
    
        #Get Director
        try:
            crew_string = crew_soup.find(text=re.compile('Director'))
            director_list = crew_string.findNext().text
            director_list = director_list.split()
            top_director = director_list[0] + " " + director_list[1]
        except:
            top_director = np.nan
        
        #Get Actor
        try:
            actor_string = crew_soup.find(text=re.compile('Character'))
            actor_list = actor_string.findNext().text
            actor_list = actor_list.split()
            top_actor = actor_list[0] + " " + actor_list[1]
        except:
            top_actor = np.nan
    
        #Create movie dictionary and return
        movie_dict = dict(zip(headers,[the_title,rate,gross_domestic_pay,gross_worldwide_pay, 
                                   budget, rankings, minutes, dist,genre_string, top_director,top_actor]))
        time.sleep(5)
        return movie_dict
    except:
        pass

# %%
movies_page_info_list =[]
for link in full_link:
    movies_page_info_list.append(get_movie_dict(link))
movies_page_info_list
# Out:
# [{'title': 'See Spot Run ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33357476,
#   'worldwide_gross_pay': 43057552,
#   'budget': 35000000,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Comedy              Crime              Family',
#   'top_director': 'George Gallo',
#   'top_actor': 'David Arquette'},
#  {'title': 'Teen Wolf ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33086611,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Atlantic Releasing Corporation',
#   'genre': 'Comedy              Fantasy              Romance',
#   'top_director': 'Jeph Loeb',
#   'top_actor': 'Michael J.'},
#  {'title': 'The Second Best Exotic Marigold Hotel ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33078266,
#   'worldwide_gross_pay': 85978292,
#   'budget': 10000000,
#   'lifetime_ranking': nan,
#   'running_time': 122,
#   'distributor': 'Fox Searchlight Pictures',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Ol Parker',
#   'top_actor': 'Judi Dench'},
#  {'title': 'Tron ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33000000,
#   'worldwide_gross_pay': 33000525,
#   'budget': 17000000,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Adventure              Sci-Fi',
#   'top_director': 'Steven Lisberger',
#   'top_actor': 'Jeff Bridges'},
#  {'title': 'The Sandlot ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32950136,
#   'worldwide_gross_pay': 34348443,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'David Mickey',
#   'top_actor': 'Tom Guiry'},
#  {'title': '*batteries not included ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32945797,
#   'worldwide_gross_pay': 65088797,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy              Sci-Fi',
#   'top_director': 'Mick Garris',
#   'top_actor': 'Hume Cronyn'},
#  {'title': 'Dreamer ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32751093,
#   'worldwide_gross_pay': 38741732,
#   'budget': 32000000,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'DreamWorks Distribution',
#   'genre': 'Drama              Family              Sport',
#   'top_director': 'John Gatins',
#   'top_actor': 'Kurt Russell'},
#  {'title': 'Return to Me ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32722798,
#   'worldwide_gross_pay': 36609995,
#   'budget': 24000000,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Bonnie Hunt',
#   'top_actor': 'David Duchovny'},
#  {'title': 'Because of Winn-Dixie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32647042,
#   'worldwide_gross_pay': 33589427,
#   'budget': 14000000,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Family',
#   'top_director': 'Kate DiCamillo',
#   'top_actor': 'AnnaSophia Robb'},
#  {'title': 'The Accidental Tourist ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32632093,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 121,
#   'distributor': 'Warner Bros.',
#   'genre': 'Drama              Romance',
#   'top_director': 'Anne Tyler',
#   'top_actor': 'William Hurt'},
#  {'title': 'October Sky ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32570685,
#   'worldwide_gross_pay': 34698753,
#   'budget': 25000000,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Universal Pictures',
#   'genre': 'Biography              Drama              Family',
#   'top_director': 'Homer H.',
#   'top_actor': 'Jake Gyllenhaal'},
#  {'title': 'Nothing in Common ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32324557,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Garry Marshall',
#   'top_actor': 'Tom Hanks'},
#  {'title': 'The Age of Innocence ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32255440,
#   'worldwide_gross_pay': nan,
#   'budget': 34000000,
#   'lifetime_ranking': nan,
#   'running_time': 139,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Drama              Romance',
#   'top_director': 'Edith Wharton',
#   'top_actor': 'Daniel Day-Lewis'},
#  {'title': 'The Bad News Bears ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32211330,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 102,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'Bill Lancaster',
#   'top_actor': 'Walter Matthau'},
#  None,
#  {'title': 'The Outlaw Josey Wales ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31800000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 135,
#   'distributor': 'Warner Bros.',
#   'genre': 'Western',
#   'top_director': 'Forrest Carter',
#   'top_actor': 'Clint Eastwood'},
#  {'title': '1941 ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31755742,
#   'worldwide_gross_pay': 92455742,
#   'budget': 35000000,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Comedy              War',
#   'top_director': 'Robert Zemeckis',
#   'top_actor': 'John Belushi'},
#  {'title': 'The Bear ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31753898,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'James Oliver',
#   'top_actor': 'Tchéky Karyo'},
#  {'title': 'August Rush ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31664162,
#   'worldwide_gross_pay': 66122026,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 114,
#   'distributor': 'Warner Bros.',
#   'genre': 'Drama              Music',
#   'top_director': 'Nick Castle',
#   'top_actor': 'Freddie Highmore'},
#  {'title': 'Good Night, and Good Luck. ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31558003,
#   'worldwide_gross_pay': 54641191,
#   'budget': 7000000,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Warner Independent Pictures (WIP)',
#   'genre': 'Biography              Drama              History',
#   'top_director': 'George Clooney',
#   'top_actor': 'David Strathairn'},
#  {'title': 'High Anxiety ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31063038,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Mystery              Thriller',
#   'top_director': 'Mel Brooks',
#   'top_actor': 'Mel Brooks'},
#  {'title': 'The Pirates! Band of Misfits ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31051126,
#   'worldwide_gross_pay': 123054041,
#   'budget': 55000000,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Adventure              Animation              Comedy              Family',
#   'top_director': 'Jeff Newitt',
#   'top_actor': 'Hugh Grant'},
#  {'title': 'Conan the Destroyer ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31042035,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 103,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Fantasy',
#   'top_director': 'Robert E.',
#   'top_actor': 'Arnold Schwarzenegger'},
#  {'title': 'Home Alone 3 ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30882515,
#   'worldwide_gross_pay': 79082515,
#   'budget': 32000000,
#   'lifetime_ranking': nan,
#   'running_time': 102,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Action              Comedy              Crime              Family',
#   'top_director': 'John Hughes',
#   'top_actor': 'Alex D.'},
#  {'title': 'The Princess Bride ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30857814,
#   'worldwide_gross_pay': 30902442,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Family              Fantasy              Romance',
#   'top_director': 'William Goldman',
#   'top_actor': 'Cary Elwes'},
#  {'title': 'I Love Trouble ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30806194,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 123,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Comedy              Romance              Thriller',
#   'top_director': 'Nancy Meyers',
#   'top_actor': 'Nick Nolte'},
#  {'title': 'Dragon Ball Super: Broly ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30712119,
#   'worldwide_gross_pay': 115757940,
#   'budget': 8500000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'FUNimation Entertainment',
#   'genre': 'Action              Adventure              Animation              Family              Fantasy              Sci-Fi',
#   'top_director': 'Akira Toriyama',
#   'top_actor': 'Masako Nozawa'},
#  {'title': 'Major League II ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30626182,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Sport',
#   'top_director': 'David S.',
#   'top_actor': 'Charlie Sheen'},
#  {'title': 'Blank Check ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30577969,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Crime              Family',
#   'top_director': 'Blake Snyder',
#   'top_actor': 'Brian Bonsall'},
#  {'title': 'The Lord of the Rings ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30471420,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 132,
#   'distributor': 'United Artists',
#   'genre': 'Adventure              Animation              Fantasy',
#   'top_director': 'Chris Conkling',
#   'top_actor': 'Christopher Guard'},
#  {'title': 'The Champ ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30441738,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 121,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Drama              Sport',
#   'top_director': 'Frances Marion',
#   'top_actor': 'Jon Voight'},
#  {'title': 'Sgt. Bilko ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30356793,
#   'worldwide_gross_pay': 37956793,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Nat Hiken',
#   'top_actor': 'Steve Martin'},
#  {'title': 'Being There ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30177511,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 130,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama',
#   'top_director': 'Jerzy Kosinski',
#   'top_actor': 'Peter Sellers'},
#  {'title': 'When the Game Stands Tall ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30127963,
#   'worldwide_gross_pay': 30138754,
#   'budget': 15000000,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Biography              Drama              Family              Sport',
#   'top_director': 'Scott Marshall',
#   'top_actor': 'Jim Caviezel'},
#  {'title': 'Free Willy 2: The Adventure Home ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30077111,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'Keith Walker',
#   'top_actor': 'Jason James'},
#  {'title': 'The Gods Must Be Crazy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30031783,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Comedy',
#   'top_director': 'Jamie Uys',
#   'top_actor': 'N!xau XiSee'},
#  {'title': 'Madeline ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29967750,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Comedy              Family',
#   'top_director': 'Ludwig Bemelmans',
#   'top_actor': 'Frances McDormand'},
#  {'title': 'Teen Titans GO! To the Movies ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29790236,
#   'worldwide_gross_pay': 52090236,
#   'budget': 10000000,
#   'lifetime_ranking': nan,
#   'running_time': 84,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Animation              Comedy              Family              Fantasy              Musical              Sci-Fi',
#   'top_director': 'Peter Rida',
#   'top_actor': 'Greg Cipes'},
#  {'title': 'Harry and the Hendersons ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29760613,
#   'worldwide_gross_pay': 49998613,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 110,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy',
#   'top_director': 'William Dear',
#   'top_actor': 'John Lithgow'},
#  {'title': 'Never Cry Wolf ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29600000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Drama',
#   'top_director': 'Farley Mowat',
#   'top_actor': 'Charles Martin'},
#  {'title': 'Twilight Zone: The Movie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29450919,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Warner Bros.',
#   'genre': 'Horror              Sci-Fi',
#   'top_director': 'John Landis',
#   'top_actor': 'Dan Aykroyd'},
#  {'title': 'Spice World ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29342592,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Comedy              Family              Music',
#   'top_director': 'Spice Girls',
#   'top_actor': 'Mel B'},
#  {'title': 'Confessions of a Teenage Drama Queen ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29331068,
#   'worldwide_gross_pay': 33251890,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family              Music              Romance',
#   'top_director': 'Dyan Sheldon',
#   'top_actor': 'Lindsay Lohan'},
#  {'title': 'Zathura: A Space Adventure ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29258869,
#   'worldwide_gross_pay': 65079104,
#   'budget': 65000000,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Action              Adventure              Comedy              Family              Fantasy              Sci-Fi',
#   'top_director': 'Chris Van',
#   'top_actor': 'Josh Hutcherson'},
#  {'title': 'Nanny McPhee Returns ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29011215,
#   'worldwide_gross_pay': 93251121,
#   'budget': 35000000,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy              War',
#   'top_director': 'Emma Thompson',
#   'top_actor': 'Emma Thompson'},
#  {'title': '3 Ninjas ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29000301,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 84,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Comedy              Family              Sport',
#   'top_director': 'Kenny Kim',
#   'top_actor': 'Victor Wong'},
#  {'title': 'James and the Giant Peach ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28946127,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 79,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Animation              Family              Fantasy              Musical',
#   'top_director': 'Roald Dahl',
#   'top_actor': 'Paul Terry'},
#  {'title': 'In the Army Now ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28881266,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              War',
#   'top_director': 'Steve Zacharias',
#   'top_actor': 'Genre keyword'},
#  {'title': 'One Direction: This Is Us ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28873374,
#   'worldwide_gross_pay': 68567841,
#   'budget': 10000000,
#   'lifetime_ranking': nan,
#   'running_time': 92,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Documentary              Music',
#   'top_director': 'Simon Cowell',
#   'top_actor': 'Liam Payne'},
#  {'title': 'Starman ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28744356,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Romance              Sci-Fi',
#   'top_director': 'Bruce A.',
#   'top_actor': 'Jeff Bridges'},
#  {'title': 'The Last Starfighter ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28733290,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Sci-Fi',
#   'top_director': 'Jonathan R.',
#   'top_actor': 'Lance Guest'},
#  {'title': 'Hoosiers ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28607524,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 114,
#   'distributor': 'Orion Pictures',
#   'genre': 'Drama              Sport',
#   'top_director': 'Angelo Pizzo',
#   'top_actor': 'Gene Hackman'},
#  {'title': 'House Calls ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28460702,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Max Shulman',
#   'top_actor': 'Walter Matthau'},
#  {'title': 'High Road to China ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28445927,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Drama              Romance              War',
#   'top_director': 'Jon Cleary',
#   'top_actor': 'Tom Selleck'},
#  {'title': 'The Crocodile Hunter: Collision Course ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28442574,
#   'worldwide_gross_pay': 33082548,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Action              Adventure              Comedy              Family',
#   'top_director': 'John Stainton',
#   'top_actor': 'Steve Irwin'},
#  {'title': 'Garfield: A Tail of Two Kitties ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28426747,
#   'worldwide_gross_pay': 143325970,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 82,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Animation              Comedy              Family',
#   'top_director': 'Steven Rimdzius',
#   'top_actor': 'Genre keyword'},
#  {'title': 'The Nut Job 2: Nutty by Nature ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28370522,
#   'worldwide_gross_pay': 68743485,
#   'budget': 40000000,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Open Road Films (II)',
#   'genre': 'Adventure              Animation              Comedy              Crime              Family',
#   'top_director': 'Scott Bindley',
#   'top_actor': 'Will Arnett'},
#  {'title': 'Victor Victoria ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28215453,
#   'worldwide_gross_pay': 28229046,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Music              Romance',
#   'top_director': 'Blake Edwards',
#   'top_actor': 'Julie Andrews'},
#  {'title': 'Ernest Saves Christmas ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28202109,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family              Fantasy',
#   'top_director': 'Ed Turner',
#   'top_actor': 'Genre keyword'},
#  {'title': 'The Prince and Me ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28176497,
#   'worldwide_gross_pay': 37666766,
#   'budget': 22000000,
#   'lifetime_ranking': nan,
#   'running_time': 111,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Family              Romance',
#   'top_director': 'Mark Amin',
#   'top_actor': 'Julia Stiles'},
#  {'title': 'The Ant Bully ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28142535,
#   'worldwide_gross_pay': 55181129,
#   'budget': 50000000,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'John A.',
#   'top_actor': 'Paul Giamatti'},
#  {'title': 'Johnny English ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28082366,
#   'worldwide_gross_pay': 160466000,
#   'budget': 40000000,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Comedy',
#   'top_director': 'Neal Purvis',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Cannonball Run II ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28078073,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Comedy',
#   'top_director': 'Ralph Bakshi',
#   'top_actor': 'Burt Reynolds'},
#  {'title': 'Police Academy 4: Citizens on Patrol ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28061343,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Crime',
#   'top_director': 'Neal Israel',
#   'top_actor': 'Genre keyword'},
#  {'title': 'The Majestic ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27807266,
#   'worldwide_gross_pay': 37317673,
#   'budget': 72000000,
#   'lifetime_ranking': nan,
#   'running_time': 152,
#   'distributor': 'Warner Bros.',
#   'genre': 'Drama              Romance',
#   'top_director': 'Michael Sloane',
#   'top_actor': 'Jim Carrey'},
#  {'title': 'Murder on the Orient Express ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27634716,
#   'worldwide_gross_pay': 27659517,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 128,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Crime              Drama              Mystery',
#   'top_director': 'Paul Dehn',
#   'top_actor': 'Albert Finney'},
#  {'title': 'Baby Geniuses ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27250736,
#   'worldwide_gross_pay': 36450736,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 97,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Comedy              Crime              Family              Sci-Fi',
#   'top_director': 'Steven Paul',
#   'top_actor': 'Kathleen Turner'},
#  {'title': 'The Bridge on the River Kwai ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27200000,
#   'worldwide_gross_pay': nan,
#   'budget': 3000000,
#   'lifetime_ranking': nan,
#   'running_time': 161,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Adventure              Drama              War',
#   'top_director': 'Pierre Boulle',
#   'top_actor': 'William Holden'},
#  {'title': 'A Passage to India ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27187653,
#   'worldwide_gross_pay': 27201487,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 164,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Adventure              Drama              History',
#   'top_director': 'E.M. Forster',
#   'top_actor': 'Judy Davis'},
#  {'title': 'Cats ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27166770,
#   'worldwide_gross_pay': 73833415,
#   'budget': 95000000,
#   'lifetime_ranking': nan,
#   'running_time': 110,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Drama              Family              Fantasy              Musical',
#   'top_director': 'Lee Hall',
#   'top_actor': 'James Corden'},
#  {'title': 'Airplane II: The Sequel ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27150534,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 85,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Sci-Fi',
#   'top_director': 'Ken Finkleman',
#   'top_actor': 'Robert Hays'},
#  {'title': 'The Jazz Singer ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27118000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'Universal Pictures',
#   'genre': 'Drama              Music              Romance',
#   'top_director': 'Sidney J.',
#   'top_actor': 'Laurence Olivier'},
#  {'title': 'Flash Gordon ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27107960,
#   'worldwide_gross_pay': 27181317,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 111,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Sci-Fi',
#   'top_director': 'Lorenzo Semple',
#   'top_actor': 'Sam J.'},
#  {'title': 'Paulie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26875268,
#   'worldwide_gross_pay': nan,
#   'budget': 23000000,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'DreamWorks Distribution',
#   'genre': 'Adventure              Comedy              Drama              Family',
#   'top_director': 'Laurie Craig',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Going in Style ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26869286,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 97,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Crime              Drama',
#   'top_director': 'Martin Brest',
#   'top_actor': 'George Burns'},
#  {'title': 'Overboard ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26713187,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 112,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Leslie Dixon',
#   'top_actor': 'Goldie Hawn'},
#  {'title': 'Baby Boom ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26712476,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 110,
#   'distributor': 'United Artists',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Nancy Meyers',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Harriet the Spy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26570048,
#   'worldwide_gross_pay': nan,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Drama              Family',
#   'top_director': 'Louise Fitzhugh',
#   'top_actor': 'Michelle Trachtenberg'},
#  {'title': 'First Kid ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26491793,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family',
#   'top_director': 'Tim Kelleher',
#   'top_actor': 'Sinbad Sam'},
#  {'title': 'Sinbad: Legend of the Seven Seas ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26483452,
#   'worldwide_gross_pay': 80773077,
#   'budget': 60000000,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'DreamWorks Distribution',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'Tim Johnson',
#   'top_actor': 'Brad Pitt'},
#  {'title': 'The Art of Racing in the Rain ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26395642,
#   'worldwide_gross_pay': 33766787,
#   'budget': 18000000,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Romance              Sport',
#   'top_director': 'Mark Bomback',
#   'top_actor': 'Kevin Costner'},
#  {'title': 'I.Q. ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26381221,
#   'worldwide_gross_pay': nan,
#   'budget': 25000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Andy Breckman',
#   'top_actor': 'Tim Robbins'},
#  {'title': 'Houseguest ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26325256,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 113,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Michael J.',
#   'top_actor': 'Sinbad Kevin'},
#  {'title': 'Protocol ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26186631,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy',
#   'top_director': 'Buck Henry',
#   'top_actor': 'Goldie Hawn'},
#  {'title': 'Modern Problems ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26154211,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Fantasy              Sci-Fi',
#   'top_director': 'Ken Shapiro',
#   'top_actor': 'Chevy Chase'},
#  {'title': 'Howards End ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26126837,
#   'worldwide_gross_pay': 26341736,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 142,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Drama              Romance',
#   'top_director': 'E.M. Forster',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'The Elephant Man ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26010864,
#   'worldwide_gross_pay': 26023706,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 124,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Biography              Drama',
#   'top_director': 'Christopher De',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'The Adventures of Rocky & Bullwinkle ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26005820,
#   'worldwide_gross_pay': 35134820,
#   'budget': 76000000,
#   'lifetime_ranking': nan,
#   'running_time': 92,
#   'distributor': 'Universal Pictures',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'Jay Ward',
#   'top_actor': 'Robert De'},
#  {'title': 'The Turning Point ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25933445,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 119,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Drama              Romance',
#   'top_director': 'Arthur Laurents',
#   'top_actor': 'Anne Bancroft'},
#  {'title': 'Leap Year ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25918920,
#   'worldwide_gross_pay': 32686500,
#   'budget': 19000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Deborah Kaplan',
#   'top_actor': 'Amy Adams'},
#  {'title': 'Innerspace ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25893810,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': nan,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Comedy              Sci-Fi              Thriller',
#   'top_director': 'Chip Proser',
#   'top_actor': 'Dennis Quaid'},
#  {'title': 'That Thing You Do! ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25857416,
#   'worldwide_gross_pay': 34585416,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Music',
#   'top_director': 'Tom Hanks',
#   'top_actor': 'Tom Hanks'},
#  {'title': 'Shadowlands ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25842377,
#   'worldwide_gross_pay': nan,
#   'budget': 22000000,
#   'lifetime_ranking': nan,
#   'running_time': 131,
#   'distributor': 'Savoy Pictures',
#   'genre': 'Biography              Drama              Romance',
#   'top_director': 'William Nicholson',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'You Again ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25702053,
#   'worldwide_gross_pay': 32054369,
#   'budget': 20000000,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Moe Jelline',
#   'top_actor': 'Kristen Bell'},
#  {'title': 'The Outsiders ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25697647,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Warner Bros.',
#   'genre': 'Crime              Drama',
#   'top_director': 'Kathleen Rowell',
#   'top_actor': 'C. Thomas'},
#  {'title': 'Crocodile Dundee in Los Angeles ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25635682,
#   'worldwide_gross_pay': 39438674,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Action              Adventure              Comedy              Crime',
#   'top_director': 'Paul Hogan',
#   'top_actor': 'Paul Hogan'},
#  {'title': 'Nancy Drew ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25612520,
#   'worldwide_gross_pay': 30666930,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 99,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Crime              Family              Mystery              Romance              Thriller',
#   'top_director': 'Andrew Fleming',
#   'top_actor': 'Emma Roberts'},
#  {'title': 'Funny Farm ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25537221,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy',
#   'top_director': 'Jay Cronley',
#   'top_actor': 'Chevy Chase'},
#  {'title': 'My Father the Hero ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25479558,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Gérard Lauzier',
#   'top_actor': 'Gérard Depardieu'},
#  {'title': 'Part of Me ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25326071,
#   'worldwide_gross_pay': 32726956,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Documentary              Music',
#   'top_director': 'Jane Lipsitz',
#   'top_actor': 'Katy Perry'},
#  {'title': 'Aliens in the Attic ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25200412,
#   'worldwide_gross_pay': 57881056,
#   'budget': 45000000,
#   'lifetime_ranking': nan,
#   'running_time': 86,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Comedy              Family              Fantasy              Sci-Fi',
#   'top_director': 'Mark Burton',
#   'top_actor': 'Ashley Tisdale'},
#  {'title': 'Fly Away Home ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25143818,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'Bill Lishman',
#   'top_actor': 'Jeff Daniels'},
#  {'title': 'Alpha and Omega ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25107267,
#   'worldwide_gross_pay': 50507267,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Lionsgate',
#   'genre': 'Adventure              Animation              Comedy              Family              Romance',
#   'top_director': 'Ben Gluck',
#   'top_actor': 'Hayden Panettiere'},
#  {'title': 'The Cutting Edge ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25105517,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama              Romance              Sport',
#   'top_director': 'Tony Gilroy',
#   'top_actor': 'D.B. Sweeney'},
#  {'title': 'Ernest Goes to Jail ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25029569,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 81,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Crime              Family',
#   'top_director': 'Charlie Cohen',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Little Man Tate ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25010896,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 99,
#   'distributor': 'Orion Pictures',
#   'genre': 'Drama',
#   'top_director': 'Scott Frank',
#   'top_actor': 'Jodie Foster'},
#  {'title': 'Invasion of the Body Snatchers ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24946533,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'United Artists',
#   'genre': 'Horror              Sci-Fi',
#   'top_director': 'W.D. Richter',
#   'top_actor': 'Donald Sutherland'},
#  {'title': 'From Russia with Love ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24796765,
#   'worldwide_gross_pay': 24808767,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'United Artists',
#   'genre': 'Action              Adventure              Thriller',
#   'top_director': 'Richard Maibaum',
#   'top_actor': 'Sean Connery'},
#  {'title': 'Waking Ned Devine ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24792251,
#   'worldwide_gross_pay': 55257450,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Fox Searchlight Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Kirk Jones',
#   'top_actor': 'Ian Bannen'},
#  {'title': 'Ghost Dad ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24707633,
#   'worldwide_gross_pay': 25421633,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 83,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy',
#   'top_director': 'Brent Maddock',
#   'top_actor': 'Bill Cosby'},
#  {'title': 'Leap! ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24702560,
#   'worldwide_gross_pay': 106127278,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Entertainment One',
#   'genre': 'Adventure              Animation              Comedy              Family              Music',
#   'top_director': 'Éric Warin',
#   'top_actor': 'Elle Fanning'},
#  {'title': 'Summer Rental ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24689703,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 87,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Jeremy Stevens',
#   'top_actor': 'John Candy'},
#  {'title': 'Operation Dumbo Drop ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24670346,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Adventure              Comedy              Drama              Family              War',
#   'top_director': 'James Morris',
#   'top_actor': 'Danny Glover'},
#  {'title': 'Lucky Lady ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24441725,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Crime              Drama',
#   'top_director': 'Willard Huyck',
#   'top_actor': 'Gene Hackman'},
#  {'title': 'The Spy Next Door ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24307086,
#   'worldwide_gross_pay': 66166000,
#   'budget': 28000000,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Lionsgate',
#   'genre': 'Action              Comedy              Family',
#   'top_director': 'Jonathan Bernstein',
#   'top_actor': 'Jackie Chan'},
#  {'title': 'Bronco Billy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24265659,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 116,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Comedy              Drama              Romance              Western',
#   'top_director': 'Dennis Hackin',
#   'top_actor': 'Clint Eastwood'},
#  {'title': 'An Inconvenient Truth ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24146161,
#   'worldwide_gross_pay': 49782012,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'Paramount Classics',
#   'genre': 'Documentary              News',
#   'top_director': 'Al Gore',
#   'top_actor': 'Al Gore'},
#  {'title': 'The Adventures of Huck Finn ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24103594,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Comedy              Drama              Family',
#   'top_director': 'Mark Twain',
#   'top_actor': 'Elijah Wood'},
#  {'title': 'Around the World in 80 Days ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24008137,
#   'worldwide_gross_pay': 72178895,
#   'budget': 110000000,
#   'lifetime_ranking': nan,
#   'running_time': nan,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Adventure              Comedy              Family              Western',
#   'top_director': 'Jules Verne',
#   'top_actor': 'Jackie Chan'},
#  {'title': 'Tom and Huck ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23920048,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 97,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Comedy              Drama              Family              Romance              Western',
#   'top_director': 'Mark Twain',
#   'top_actor': 'Jonathan Taylor'},
#  {'title': 'Santa Claus: The Movie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23717291,
#   'worldwide_gross_pay': nan,
#   'budget': 50000000,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Adventure              Family              Fantasy',
#   'top_director': 'David Newman',
#   'top_actor': 'Dudley Moore'},
#  {'title': 'Good Burger ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23712993,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Family',
#   'top_director': 'Dan Schneider',
#   'top_actor': 'Kel Mitchell'},
#  {'title': 'Sixteen Candles ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23686027,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'John Hughes',
#   'top_actor': 'Molly Ringwald'},
#  {'title': 'Two of a Kind ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23646952,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Fantasy              Romance',
#   'top_director': 'John Herzfeld',
#   'top_actor': 'John Travolta'},
#  {'title': 'Agent Cody Banks 2: Destination London ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23630159,
#   'worldwide_gross_pay': 28818995,
#   'budget': 26000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Action              Adventure              Comedy              Family              Romance              Sci-Fi',
#   'top_director': 'Jeffrey Jurgensen',
#   'top_actor': 'Frankie Muniz'},
#  {'title': 'Oscar ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23562716,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Crime',
#   'top_director': 'Claude Magnier',
#   'top_actor': 'Sylvester Stallone'},
#  {'title': 'Ernest Goes to Camp ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23509382,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 92,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family',
#   'top_director': 'John R.',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Benny & Joon ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23261580,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Barry Berman',
#   'top_actor': 'Johnny Depp'},
#  {'title': 'Kingdom Come ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23249649,
#   'worldwide_gross_pay': 23396049,
#   'budget': 7000000,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Fox Searchlight Pictures',
#   'genre': 'Comedy              Drama',
#   'top_director': 'David Dean',
#   'top_actor': 'LL Cool'},
#  {'title': 'The Remains of the Day ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23237911,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Drama              Romance',
#   'top_director': 'Kazuo Ishiguro',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'Monte Carlo ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23186769,
#   'worldwide_gross_pay': 39782683,
#   'budget': 20000000,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Comedy              Family              Romance',
#   'top_director': 'Thomas Bezucha',
#   'top_actor': 'Selena Gomez'},
#  {'title': 'The Iron Giant ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23159305,
#   'worldwide_gross_pay': 23180087,
#   'budget': 70000000,
#   'lifetime_ranking': nan,
#   'running_time': 86,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Animation              Comedy              Drama              Family              Sci-Fi',
#   'top_director': 'Tim McCanlies',
#   'top_actor': 'Eli Marienthal'},
#  {'title': 'Air Bud ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23144499,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'Kevin DiCicco',
#   'top_actor': 'Michael Jeter'},
#  {'title': 'D3: The Mighty Ducks ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 22955097,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
# ...
#   'domestic_gross_pay': 1083486,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Biography              Drama              Romance',
#   'top_director': 'Helene Hanff',
#   'top_actor': 'Anne Bancroft'},
#  {'title': 'Housekeeping ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1083282,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 116,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Comedy              Drama',
#   'top_director': 'Marilynne Robinson',
#   'top_actor': 'Christine Lahti'},
#  {'title': 'The Tango Lesson ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1080192,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Drama              Music              Romance',
#   'top_director': 'Sally Potter',
#   'top_actor': 'Sally Potter'},
#  {'title': 'Wonderstruck ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1060377,
#   'worldwide_gross_pay': 3285916,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 116,
#   'distributor': 'Roadside Attractions',
#   'genre': 'Adventure              Drama              Mystery',
#   'top_director': 'Brian Selznick',
#   'top_actor': 'Oakes Fegley'},
#  {'title': 'Comfort and Joy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1057368,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Bill Forsyth',
#   'top_actor': 'Bill Paterson'},
#  {'title': 'Caramel ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1055580,
#   'worldwide_gross_pay': 14248749,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Roadside Attractions',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Nadine Labaki',
#   'top_actor': 'Nadine Labaki'},
#  {'title': 'Extremedays ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1047553,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Providence Entertainment',
#   'genre': 'Action              Adventure              Comedy              Drama              Romance              Sport',
#   'top_director': 'Eric Hannah',
#   'top_actor': 'Dante Basco'},
#  {'title': 'The Perfect Game ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1037071,
#   'worldwide_gross_pay': 3878993,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'IndustryWorks Pictures',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'W. William',
#   'top_actor': 'Clifton Collins'},
#  {'title': 'Dark Horse ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1030851,
#   'worldwide_gross_pay': 1034197,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 85,
#   'distributor': 'Mongrel Media',
#   'genre': 'Documentary              Drama',
#   'top_director': 'Louise Osmond',
#   'top_actor': 'Jan Vokes'},
#  {'title': 'Nothing to Lose ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1016188,
#   'worldwide_gross_pay': 36075317,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Swen Releasing',
#   'genre': 'Biography              Drama',
#   'top_director': 'Stephen P.',
#   'top_actor': 'Petrônio Gontijo'},
#  {'title': 'Yu-Gi-Oh!: The Dark Side of Dimensions ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1015339,
#   'worldwide_gross_pay': 7445186,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 130,
#   'distributor': 'Screenvision',
#   'genre': 'Adventure              Animation              Drama              Fantasy',
#   'top_director': 'Kazuki Takahashi',
#   'top_actor': 'Shunsuke Kazama'},
#  {'title': 'Shiloh ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1007822,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Legacy',
#   'genre': 'Drama              Family',
#   'top_director': 'Phyllis Reynolds',
#   'top_actor': 'Blake Heron'},
#  {'title': 'From Up on Poppy Hill ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1002895,
#   'worldwide_gross_pay': 61487846,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'GKIDS',
#   'genre': 'Animation              Drama              Family              Romance',
#   'top_director': 'Tetsurô Sayama',
#   'top_actor': 'Sarah Bolger'},
#  {'title': 'March or Die ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1000000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Adventure              Drama              Romance              War',
#   'top_director': 'David Zelag',
#   'top_actor': 'Gene Hackman'},
#  {'title': 'Campus Man ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 989528,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Matt Dorff',
#   'top_actor': 'John Dye'},
#  {'title': 'Million Dollar Mystery ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 989033,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'De Laurentiis Entertainment Group (DEG)',
#   'genre': 'Comedy              Mystery',
#   'top_director': 'Tim Metcalfe',
#   'top_actor': 'Eddie Deezen'},
#  {'title': "Meek's Cutoff ",
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 977772,
#   'worldwide_gross_pay': 1205257,
#   'budget': 2000000,
#   'lifetime_ranking': nan,
#   'running_time': 104,
#   'distributor': 'Oscilloscope',
#   'genre': 'Adventure              Drama              Thriller              Western',
#   'top_director': 'Jonathan Raymond',
#   'top_actor': 'Michelle Williams'},
#  {'title': 'The Tale of The Princess Kaguya ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 974913,
#   'worldwide_gross_pay': 24706166,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 137,
#   'distributor': 'GKIDS',
#   'genre': 'Adventure              Animation              Drama              Family              Fantasy',
#   'top_director': 'Isao Takahata',
#   'top_actor': 'Chloë Grace'},
#  {'title': 'Appointment with Death ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 960040,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 102,
#   'distributor': 'Cannon Film Distributors',
#   'genre': 'Crime              Drama              Mystery              Thriller',
#   'top_director': 'Agatha Christie',
#   'top_actor': 'Peter Ustinov'},
#  {'title': 'The Fighting Preacher ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 954641,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Purdie Distribution',
#   'genre': 'Comedy              Drama              History',
#   'top_director': 'T.C. Christensen',
#   'top_actor': 'David McConnell'},
#  {'title': 'Faces Places ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 953717,
#   'worldwide_gross_pay': 3996577,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Cohen Media Group',
#   'genre': 'Documentary',
#   'top_director': 'Cast information',
#   'top_actor': 'Agnès Varda'},
#  {'title': 'The Ten Commandments ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 952820,
#   'worldwide_gross_pay': 1051907,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Rocky Mountain Pictures',
#   'genre': 'Animation              Family',
#   'top_director': 'John Stronach',
#   'top_actor': 'Ben Kingsley'},
#  {'title': 'More Than a Game ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 950675,
#   'worldwide_gross_pay': 960387,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Lionsgate',
#   'genre': 'Biography              Documentary              Sport',
#   'top_director': 'Kristopher Belman',
#   'top_actor': 'LeBron James'},
#  {'title': 'Children of Heaven ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 933933,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Miramax',
#   'genre': 'Drama              Family              Sport',
#   'top_director': 'Majid Majidi',
#   'top_actor': 'Mohammad Amir'},
#  {'title': 'An Egg Rescue ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 926514,
#   'worldwide_gross_pay': 3349309,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Pantelion Films',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'Rodolfo Riva',
#   'top_actor': 'Marcelo Barcelo'},
#  {'title': 'The Red Turtle ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 921974,
#   'worldwide_gross_pay': 6591789,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 80,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Animation              Family              Fantasy',
#   'top_director': 'Michael Dudok',
#   'top_actor': 'Emmanuel Garijo'},
#  {'title': 'Boruto: Naruto The Movie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 919651,
#   'worldwide_gross_pay': 38362448,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Eleven Arts',
#   'genre': 'Action              Adventure              Animation              Comedy',
#   'top_director': 'Toshiyuki Tsuru',
#   'top_actor': 'Yûko Sanpei'},
#  {'title': 'Brain Donors ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 918239,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 80,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Pat Proft',
#   'top_actor': 'John Turturro'},
#  {'title': 'Lagaan: Once Upon a Time in India ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 909043,
#   'worldwide_gross_pay': 1724806,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 224,
#   'distributor': 'Set Pictures',
#   'genre': 'Drama              Musical              Sport',
#   'top_director': 'Ashutosh Gowariker',
#   'top_actor': 'Aamir Khan'},
#  {'title': 'The War Room ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 901668,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'October Films',
#   'genre': 'Documentary              History',
#   'top_director': 'D.A. Pennebaker',
#   'top_actor': 'James Carville'},
#  {'title': 'The Wildest Dream ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 898137,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'National Geographic Entertainment',
#   'genre': 'Biography              Documentary',
#   'top_director': 'Mark MacKenzie',
#   'top_actor': 'Conrad Anker'},
#  {'title': 'The Glass Menagerie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 895904,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Cineplex Odeon Films',
#   'genre': 'Drama',
#   'top_director': 'Tennessee Williams',
#   'top_actor': 'Joanne Woodward'},
#  {'title': 'Believe ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 890303,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 119,
#   'distributor': 'Freestyle Releasing',
#   'genre': 'Drama',
#   'top_director': 'Billy Dickson',
#   'top_actor': "Ryan O'Quinn"},
#  {'title': 'Saawariya ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 885574,
#   'worldwide_gross_pay': 18525631,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 142,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Drama              Musical              Romance',
#   'top_director': 'Fyodor Dostoevsky',
#   'top_actor': 'Ranbir Kapoor'},
#  {'title': 'Princess Kaiulani ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 883887,
#   'worldwide_gross_pay': nan,
#   'budget': 9000000,
#   'lifetime_ranking': nan,
#   'running_time': 130,
#   'distributor': 'Roadside Attractions',
#   'genre': 'Biography              Drama              History              Romance',
#   'top_director': 'Marc Forby',
#   'top_actor': "Q'orianka Kilcher"},
#  {'title': 'Emma Smith: My Story ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 881787,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Candlelight Media Group',
#   'genre': 'Biography              Drama              History',
#   'top_director': 'T.C. Christensen',
#   'top_actor': 'Patricia Place'},
#  {'title': 'Fast, Cheap & Out of Control ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 878960,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 80,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Documentary',
#   'top_director': 'Errol Morris',
#   'top_actor': 'Dave Hoover'},
#  {'title': 'Duma ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 870067,
#   'worldwide_gross_pay': 994790,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'Carol Cawthra',
#   'top_actor': 'Alex Michaeletos'},
#  {'title': 'Mirrormask ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 866999,
#   'worldwide_gross_pay': nan,
#   'budget': 4000000,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'IDP Distribution',
#   'genre': 'Adventure              Fantasy',
#   'top_director': 'Neil Gaiman',
#   'top_actor': 'Stephanie Leonidas'},
#  {'title': 'Sarah Landon and the Paranormal Hour ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 858415,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 81,
#   'distributor': 'Freestyle Releasing',
#   'genre': 'Action              Adventure              Family              Fantasy              Horror              Mystery              Thriller',
#   'top_director': 'John Comrie',
#   'top_actor': 'Rissa Walters'},
#  {'title': 'Song of the Sea ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 857522,
#   'worldwide_gross_pay': 4190884,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'GKIDS',
#   'genre': 'Adventure              Animation              Drama              Family              Fantasy',
#   'top_director': 'Will Collins',
#   'top_actor': 'David Rawle'},
#  None,
#  {'title': 'Sharkwater ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 850920,
#   'worldwide_gross_pay': 1658393,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Freestyle Releasing',
#   'genre': 'Documentary',
#   'top_director': 'Rob Stewart',
#   'top_actor': 'Rob Stewart'},
#  {'title': 'Scoob! ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 850000,
#   'worldwide_gross_pay': 25750000,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Animation              Comedy              Crime              Family              Fantasy              Mystery              Sci-Fi',
#   'top_director': 'Adam Sztykiel',
#   'top_actor': 'Will Forte'},
#  {'title': 'Guadalupe: El Milagro Y El Mensaje ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 848139,
#   'worldwide_gross_pay': 1499149,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Slowhand Cinema Releasing',
#   'genre': 'Drama              Family              Fantasy              Mystery',
#   'top_director': 'Tessie Gutierrez',
#   'top_actor': 'José Carlos'},
#  {'title': 'Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 840958,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Cinecom Pictures',
#   'genre': 'Comedy              Drama',
#   'top_director': 'Ed Graczyk',
#   'top_actor': 'Cher SissySee'}]

# %%
movies_page_info_list
# Out:
# [{'title': 'See Spot Run ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33357476,
#   'worldwide_gross_pay': 43057552,
#   'budget': 35000000,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Comedy              Crime              Family',
#   'top_director': 'George Gallo',
#   'top_actor': 'David Arquette'},
#  {'title': 'Teen Wolf ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33086611,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Atlantic Releasing Corporation',
#   'genre': 'Comedy              Fantasy              Romance',
#   'top_director': 'Jeph Loeb',
#   'top_actor': 'Michael J.'},
#  {'title': 'The Second Best Exotic Marigold Hotel ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33078266,
#   'worldwide_gross_pay': 85978292,
#   'budget': 10000000,
#   'lifetime_ranking': nan,
#   'running_time': 122,
#   'distributor': 'Fox Searchlight Pictures',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Ol Parker',
#   'top_actor': 'Judi Dench'},
#  {'title': 'Tron ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33000000,
#   'worldwide_gross_pay': 33000525,
#   'budget': 17000000,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Adventure              Sci-Fi',
#   'top_director': 'Steven Lisberger',
#   'top_actor': 'Jeff Bridges'},
#  {'title': 'The Sandlot ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32950136,
#   'worldwide_gross_pay': 34348443,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'David Mickey',
#   'top_actor': 'Tom Guiry'},
#  {'title': '*batteries not included ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32945797,
#   'worldwide_gross_pay': 65088797,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy              Sci-Fi',
#   'top_director': 'Mick Garris',
#   'top_actor': 'Hume Cronyn'},
#  {'title': 'Dreamer ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32751093,
#   'worldwide_gross_pay': 38741732,
#   'budget': 32000000,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'DreamWorks Distribution',
#   'genre': 'Drama              Family              Sport',
#   'top_director': 'John Gatins',
#   'top_actor': 'Kurt Russell'},
#  {'title': 'Return to Me ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32722798,
#   'worldwide_gross_pay': 36609995,
#   'budget': 24000000,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Bonnie Hunt',
#   'top_actor': 'David Duchovny'},
#  {'title': 'Because of Winn-Dixie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32647042,
#   'worldwide_gross_pay': 33589427,
#   'budget': 14000000,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Family',
#   'top_director': 'Kate DiCamillo',
#   'top_actor': 'AnnaSophia Robb'},
#  {'title': 'The Accidental Tourist ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32632093,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 121,
#   'distributor': 'Warner Bros.',
#   'genre': 'Drama              Romance',
#   'top_director': 'Anne Tyler',
#   'top_actor': 'William Hurt'},
#  {'title': 'October Sky ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32570685,
#   'worldwide_gross_pay': 34698753,
#   'budget': 25000000,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Universal Pictures',
#   'genre': 'Biography              Drama              Family',
#   'top_director': 'Homer H.',
#   'top_actor': 'Jake Gyllenhaal'},
#  {'title': 'Nothing in Common ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32324557,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Garry Marshall',
#   'top_actor': 'Tom Hanks'},
#  {'title': 'The Age of Innocence ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32255440,
#   'worldwide_gross_pay': nan,
#   'budget': 34000000,
#   'lifetime_ranking': nan,
#   'running_time': 139,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Drama              Romance',
#   'top_director': 'Edith Wharton',
#   'top_actor': 'Daniel Day-Lewis'},
#  {'title': 'The Bad News Bears ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32211330,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 102,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'Bill Lancaster',
#   'top_actor': 'Walter Matthau'},
#  None,
#  {'title': 'The Outlaw Josey Wales ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31800000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 135,
#   'distributor': 'Warner Bros.',
#   'genre': 'Western',
#   'top_director': 'Forrest Carter',
#   'top_actor': 'Clint Eastwood'},
#  {'title': '1941 ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31755742,
#   'worldwide_gross_pay': 92455742,
#   'budget': 35000000,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Comedy              War',
#   'top_director': 'Robert Zemeckis',
#   'top_actor': 'John Belushi'},
#  {'title': 'The Bear ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31753898,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'James Oliver',
#   'top_actor': 'Tchéky Karyo'},
#  {'title': 'August Rush ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31664162,
#   'worldwide_gross_pay': 66122026,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 114,
#   'distributor': 'Warner Bros.',
#   'genre': 'Drama              Music',
#   'top_director': 'Nick Castle',
#   'top_actor': 'Freddie Highmore'},
#  {'title': 'Good Night, and Good Luck. ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31558003,
#   'worldwide_gross_pay': 54641191,
#   'budget': 7000000,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Warner Independent Pictures (WIP)',
#   'genre': 'Biography              Drama              History',
#   'top_director': 'George Clooney',
#   'top_actor': 'David Strathairn'},
#  {'title': 'High Anxiety ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31063038,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Mystery              Thriller',
#   'top_director': 'Mel Brooks',
#   'top_actor': 'Mel Brooks'},
#  {'title': 'The Pirates! Band of Misfits ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31051126,
#   'worldwide_gross_pay': 123054041,
#   'budget': 55000000,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Adventure              Animation              Comedy              Family',
#   'top_director': 'Jeff Newitt',
#   'top_actor': 'Hugh Grant'},
#  {'title': 'Conan the Destroyer ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31042035,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 103,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Fantasy',
#   'top_director': 'Robert E.',
#   'top_actor': 'Arnold Schwarzenegger'},
#  {'title': 'Home Alone 3 ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30882515,
#   'worldwide_gross_pay': 79082515,
#   'budget': 32000000,
#   'lifetime_ranking': nan,
#   'running_time': 102,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Action              Comedy              Crime              Family',
#   'top_director': 'John Hughes',
#   'top_actor': 'Alex D.'},
#  {'title': 'The Princess Bride ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30857814,
#   'worldwide_gross_pay': 30902442,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Family              Fantasy              Romance',
#   'top_director': 'William Goldman',
#   'top_actor': 'Cary Elwes'},
#  {'title': 'I Love Trouble ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30806194,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 123,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Comedy              Romance              Thriller',
#   'top_director': 'Nancy Meyers',
#   'top_actor': 'Nick Nolte'},
#  {'title': 'Dragon Ball Super: Broly ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30712119,
#   'worldwide_gross_pay': 115757940,
#   'budget': 8500000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'FUNimation Entertainment',
#   'genre': 'Action              Adventure              Animation              Family              Fantasy              Sci-Fi',
#   'top_director': 'Akira Toriyama',
#   'top_actor': 'Masako Nozawa'},
#  {'title': 'Major League II ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30626182,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Sport',
#   'top_director': 'David S.',
#   'top_actor': 'Charlie Sheen'},
#  {'title': 'Blank Check ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30577969,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Crime              Family',
#   'top_director': 'Blake Snyder',
#   'top_actor': 'Brian Bonsall'},
#  {'title': 'The Lord of the Rings ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30471420,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 132,
#   'distributor': 'United Artists',
#   'genre': 'Adventure              Animation              Fantasy',
#   'top_director': 'Chris Conkling',
#   'top_actor': 'Christopher Guard'},
#  {'title': 'The Champ ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30441738,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 121,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Drama              Sport',
#   'top_director': 'Frances Marion',
#   'top_actor': 'Jon Voight'},
#  {'title': 'Sgt. Bilko ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30356793,
#   'worldwide_gross_pay': 37956793,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Nat Hiken',
#   'top_actor': 'Steve Martin'},
#  {'title': 'Being There ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30177511,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 130,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama',
#   'top_director': 'Jerzy Kosinski',
#   'top_actor': 'Peter Sellers'},
#  {'title': 'When the Game Stands Tall ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30127963,
#   'worldwide_gross_pay': 30138754,
#   'budget': 15000000,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Biography              Drama              Family              Sport',
#   'top_director': 'Scott Marshall',
#   'top_actor': 'Jim Caviezel'},
#  {'title': 'Free Willy 2: The Adventure Home ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30077111,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'Keith Walker',
#   'top_actor': 'Jason James'},
#  {'title': 'The Gods Must Be Crazy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30031783,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Comedy',
#   'top_director': 'Jamie Uys',
#   'top_actor': 'N!xau XiSee'},
#  {'title': 'Madeline ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29967750,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Comedy              Family',
#   'top_director': 'Ludwig Bemelmans',
#   'top_actor': 'Frances McDormand'},
#  {'title': 'Teen Titans GO! To the Movies ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29790236,
#   'worldwide_gross_pay': 52090236,
#   'budget': 10000000,
#   'lifetime_ranking': nan,
#   'running_time': 84,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Animation              Comedy              Family              Fantasy              Musical              Sci-Fi',
#   'top_director': 'Peter Rida',
#   'top_actor': 'Greg Cipes'},
#  {'title': 'Harry and the Hendersons ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29760613,
#   'worldwide_gross_pay': 49998613,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 110,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy',
#   'top_director': 'William Dear',
#   'top_actor': 'John Lithgow'},
#  {'title': 'Never Cry Wolf ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29600000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Drama',
#   'top_director': 'Farley Mowat',
#   'top_actor': 'Charles Martin'},
#  {'title': 'Twilight Zone: The Movie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29450919,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Warner Bros.',
#   'genre': 'Horror              Sci-Fi',
#   'top_director': 'John Landis',
#   'top_actor': 'Dan Aykroyd'},
#  {'title': 'Spice World ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29342592,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Comedy              Family              Music',
#   'top_director': 'Spice Girls',
#   'top_actor': 'Mel B'},
#  {'title': 'Confessions of a Teenage Drama Queen ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29331068,
#   'worldwide_gross_pay': 33251890,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family              Music              Romance',
#   'top_director': 'Dyan Sheldon',
#   'top_actor': 'Lindsay Lohan'},
#  {'title': 'Zathura: A Space Adventure ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29258869,
#   'worldwide_gross_pay': 65079104,
#   'budget': 65000000,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Action              Adventure              Comedy              Family              Fantasy              Sci-Fi',
#   'top_director': 'Chris Van',
#   'top_actor': 'Josh Hutcherson'},
#  {'title': 'Nanny McPhee Returns ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29011215,
#   'worldwide_gross_pay': 93251121,
#   'budget': 35000000,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy              War',
#   'top_director': 'Emma Thompson',
#   'top_actor': 'Emma Thompson'},
#  {'title': '3 Ninjas ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29000301,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 84,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Comedy              Family              Sport',
#   'top_director': 'Kenny Kim',
#   'top_actor': 'Victor Wong'},
#  {'title': 'James and the Giant Peach ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28946127,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 79,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Animation              Family              Fantasy              Musical',
#   'top_director': 'Roald Dahl',
#   'top_actor': 'Paul Terry'},
#  {'title': 'In the Army Now ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28881266,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              War',
#   'top_director': 'Steve Zacharias',
#   'top_actor': 'Genre keyword'},
#  {'title': 'One Direction: This Is Us ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28873374,
#   'worldwide_gross_pay': 68567841,
#   'budget': 10000000,
#   'lifetime_ranking': nan,
#   'running_time': 92,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Documentary              Music',
#   'top_director': 'Simon Cowell',
#   'top_actor': 'Liam Payne'},
#  {'title': 'Starman ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28744356,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Romance              Sci-Fi',
#   'top_director': 'Bruce A.',
#   'top_actor': 'Jeff Bridges'},
#  {'title': 'The Last Starfighter ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28733290,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Sci-Fi',
#   'top_director': 'Jonathan R.',
#   'top_actor': 'Lance Guest'},
#  {'title': 'Hoosiers ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28607524,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 114,
#   'distributor': 'Orion Pictures',
#   'genre': 'Drama              Sport',
#   'top_director': 'Angelo Pizzo',
#   'top_actor': 'Gene Hackman'},
#  {'title': 'House Calls ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28460702,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Max Shulman',
#   'top_actor': 'Walter Matthau'},
#  {'title': 'High Road to China ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28445927,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Drama              Romance              War',
#   'top_director': 'Jon Cleary',
#   'top_actor': 'Tom Selleck'},
#  {'title': 'The Crocodile Hunter: Collision Course ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28442574,
#   'worldwide_gross_pay': 33082548,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Action              Adventure              Comedy              Family',
#   'top_director': 'John Stainton',
#   'top_actor': 'Steve Irwin'},
#  {'title': 'Garfield: A Tail of Two Kitties ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28426747,
#   'worldwide_gross_pay': 143325970,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 82,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Animation              Comedy              Family',
#   'top_director': 'Steven Rimdzius',
#   'top_actor': 'Genre keyword'},
#  {'title': 'The Nut Job 2: Nutty by Nature ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28370522,
#   'worldwide_gross_pay': 68743485,
#   'budget': 40000000,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Open Road Films (II)',
#   'genre': 'Adventure              Animation              Comedy              Crime              Family',
#   'top_director': 'Scott Bindley',
#   'top_actor': 'Will Arnett'},
#  {'title': 'Victor Victoria ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28215453,
#   'worldwide_gross_pay': 28229046,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Music              Romance',
#   'top_director': 'Blake Edwards',
#   'top_actor': 'Julie Andrews'},
#  {'title': 'Ernest Saves Christmas ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28202109,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family              Fantasy',
#   'top_director': 'Ed Turner',
#   'top_actor': 'Genre keyword'},
#  {'title': 'The Prince and Me ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28176497,
#   'worldwide_gross_pay': 37666766,
#   'budget': 22000000,
#   'lifetime_ranking': nan,
#   'running_time': 111,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Family              Romance',
#   'top_director': 'Mark Amin',
#   'top_actor': 'Julia Stiles'},
#  {'title': 'The Ant Bully ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28142535,
#   'worldwide_gross_pay': 55181129,
#   'budget': 50000000,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'John A.',
#   'top_actor': 'Paul Giamatti'},
#  {'title': 'Johnny English ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28082366,
#   'worldwide_gross_pay': 160466000,
#   'budget': 40000000,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Comedy',
#   'top_director': 'Neal Purvis',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Cannonball Run II ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28078073,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Comedy',
#   'top_director': 'Ralph Bakshi',
#   'top_actor': 'Burt Reynolds'},
#  {'title': 'Police Academy 4: Citizens on Patrol ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28061343,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Crime',
#   'top_director': 'Neal Israel',
#   'top_actor': 'Genre keyword'},
#  {'title': 'The Majestic ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27807266,
#   'worldwide_gross_pay': 37317673,
#   'budget': 72000000,
#   'lifetime_ranking': nan,
#   'running_time': 152,
#   'distributor': 'Warner Bros.',
#   'genre': 'Drama              Romance',
#   'top_director': 'Michael Sloane',
#   'top_actor': 'Jim Carrey'},
#  {'title': 'Murder on the Orient Express ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27634716,
#   'worldwide_gross_pay': 27659517,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 128,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Crime              Drama              Mystery',
#   'top_director': 'Paul Dehn',
#   'top_actor': 'Albert Finney'},
#  {'title': 'Baby Geniuses ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27250736,
#   'worldwide_gross_pay': 36450736,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 97,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Comedy              Crime              Family              Sci-Fi',
#   'top_director': 'Steven Paul',
#   'top_actor': 'Kathleen Turner'},
#  {'title': 'The Bridge on the River Kwai ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27200000,
#   'worldwide_gross_pay': nan,
#   'budget': 3000000,
#   'lifetime_ranking': nan,
#   'running_time': 161,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Adventure              Drama              War',
#   'top_director': 'Pierre Boulle',
#   'top_actor': 'William Holden'},
#  {'title': 'A Passage to India ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27187653,
#   'worldwide_gross_pay': 27201487,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 164,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Adventure              Drama              History',
#   'top_director': 'E.M. Forster',
#   'top_actor': 'Judy Davis'},
#  {'title': 'Cats ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27166770,
#   'worldwide_gross_pay': 73833415,
#   'budget': 95000000,
#   'lifetime_ranking': nan,
#   'running_time': 110,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Drama              Family              Fantasy              Musical',
#   'top_director': 'Lee Hall',
#   'top_actor': 'James Corden'},
#  {'title': 'Airplane II: The Sequel ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27150534,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 85,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Sci-Fi',
#   'top_director': 'Ken Finkleman',
#   'top_actor': 'Robert Hays'},
#  {'title': 'The Jazz Singer ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27118000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'Universal Pictures',
#   'genre': 'Drama              Music              Romance',
#   'top_director': 'Sidney J.',
#   'top_actor': 'Laurence Olivier'},
#  {'title': 'Flash Gordon ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27107960,
#   'worldwide_gross_pay': 27181317,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 111,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Sci-Fi',
#   'top_director': 'Lorenzo Semple',
#   'top_actor': 'Sam J.'},
#  {'title': 'Paulie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26875268,
#   'worldwide_gross_pay': nan,
#   'budget': 23000000,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'DreamWorks Distribution',
#   'genre': 'Adventure              Comedy              Drama              Family',
#   'top_director': 'Laurie Craig',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Going in Style ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26869286,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 97,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Crime              Drama',
#   'top_director': 'Martin Brest',
#   'top_actor': 'George Burns'},
#  {'title': 'Overboard ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26713187,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 112,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Leslie Dixon',
#   'top_actor': 'Goldie Hawn'},
#  {'title': 'Baby Boom ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26712476,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 110,
#   'distributor': 'United Artists',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Nancy Meyers',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Harriet the Spy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26570048,
#   'worldwide_gross_pay': nan,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Drama              Family',
#   'top_director': 'Louise Fitzhugh',
#   'top_actor': 'Michelle Trachtenberg'},
#  {'title': 'First Kid ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26491793,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family',
#   'top_director': 'Tim Kelleher',
#   'top_actor': 'Sinbad Sam'},
#  {'title': 'Sinbad: Legend of the Seven Seas ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26483452,
#   'worldwide_gross_pay': 80773077,
#   'budget': 60000000,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'DreamWorks Distribution',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'Tim Johnson',
#   'top_actor': 'Brad Pitt'},
#  {'title': 'The Art of Racing in the Rain ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26395642,
#   'worldwide_gross_pay': 33766787,
#   'budget': 18000000,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Romance              Sport',
#   'top_director': 'Mark Bomback',
#   'top_actor': 'Kevin Costner'},
#  {'title': 'I.Q. ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26381221,
#   'worldwide_gross_pay': nan,
#   'budget': 25000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Andy Breckman',
#   'top_actor': 'Tim Robbins'},
#  {'title': 'Houseguest ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26325256,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 113,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Michael J.',
#   'top_actor': 'Sinbad Kevin'},
#  {'title': 'Protocol ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26186631,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy',
#   'top_director': 'Buck Henry',
#   'top_actor': 'Goldie Hawn'},
#  {'title': 'Modern Problems ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26154211,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Fantasy              Sci-Fi',
#   'top_director': 'Ken Shapiro',
#   'top_actor': 'Chevy Chase'},
#  {'title': 'Howards End ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26126837,
#   'worldwide_gross_pay': 26341736,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 142,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Drama              Romance',
#   'top_director': 'E.M. Forster',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'The Elephant Man ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26010864,
#   'worldwide_gross_pay': 26023706,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 124,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Biography              Drama',
#   'top_director': 'Christopher De',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'The Adventures of Rocky & Bullwinkle ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26005820,
#   'worldwide_gross_pay': 35134820,
#   'budget': 76000000,
#   'lifetime_ranking': nan,
#   'running_time': 92,
#   'distributor': 'Universal Pictures',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'Jay Ward',
#   'top_actor': 'Robert De'},
#  {'title': 'The Turning Point ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25933445,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 119,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Drama              Romance',
#   'top_director': 'Arthur Laurents',
#   'top_actor': 'Anne Bancroft'},
#  {'title': 'Leap Year ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25918920,
#   'worldwide_gross_pay': 32686500,
#   'budget': 19000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Deborah Kaplan',
#   'top_actor': 'Amy Adams'},
#  {'title': 'Innerspace ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25893810,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': nan,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Comedy              Sci-Fi              Thriller',
#   'top_director': 'Chip Proser',
#   'top_actor': 'Dennis Quaid'},
#  {'title': 'That Thing You Do! ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25857416,
#   'worldwide_gross_pay': 34585416,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Music',
#   'top_director': 'Tom Hanks',
#   'top_actor': 'Tom Hanks'},
#  {'title': 'Shadowlands ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25842377,
#   'worldwide_gross_pay': nan,
#   'budget': 22000000,
#   'lifetime_ranking': nan,
#   'running_time': 131,
#   'distributor': 'Savoy Pictures',
#   'genre': 'Biography              Drama              Romance',
#   'top_director': 'William Nicholson',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'You Again ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25702053,
#   'worldwide_gross_pay': 32054369,
#   'budget': 20000000,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Moe Jelline',
#   'top_actor': 'Kristen Bell'},
#  {'title': 'The Outsiders ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25697647,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Warner Bros.',
#   'genre': 'Crime              Drama',
#   'top_director': 'Kathleen Rowell',
#   'top_actor': 'C. Thomas'},
#  {'title': 'Crocodile Dundee in Los Angeles ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25635682,
#   'worldwide_gross_pay': 39438674,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Action              Adventure              Comedy              Crime',
#   'top_director': 'Paul Hogan',
#   'top_actor': 'Paul Hogan'},
#  {'title': 'Nancy Drew ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25612520,
#   'worldwide_gross_pay': 30666930,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 99,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Crime              Family              Mystery              Romance              Thriller',
#   'top_director': 'Andrew Fleming',
#   'top_actor': 'Emma Roberts'},
#  {'title': 'Funny Farm ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25537221,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy',
#   'top_director': 'Jay Cronley',
#   'top_actor': 'Chevy Chase'},
#  {'title': 'My Father the Hero ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25479558,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Gérard Lauzier',
#   'top_actor': 'Gérard Depardieu'},
#  {'title': 'Part of Me ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25326071,
#   'worldwide_gross_pay': 32726956,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Documentary              Music',
#   'top_director': 'Jane Lipsitz',
#   'top_actor': 'Katy Perry'},
#  {'title': 'Aliens in the Attic ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25200412,
#   'worldwide_gross_pay': 57881056,
#   'budget': 45000000,
#   'lifetime_ranking': nan,
#   'running_time': 86,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Comedy              Family              Fantasy              Sci-Fi',
#   'top_director': 'Mark Burton',
#   'top_actor': 'Ashley Tisdale'},
#  {'title': 'Fly Away Home ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25143818,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'Bill Lishman',
#   'top_actor': 'Jeff Daniels'},
#  {'title': 'Alpha and Omega ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25107267,
#   'worldwide_gross_pay': 50507267,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Lionsgate',
#   'genre': 'Adventure              Animation              Comedy              Family              Romance',
#   'top_director': 'Ben Gluck',
#   'top_actor': 'Hayden Panettiere'},
#  {'title': 'The Cutting Edge ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25105517,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama              Romance              Sport',
#   'top_director': 'Tony Gilroy',
#   'top_actor': 'D.B. Sweeney'},
#  {'title': 'Ernest Goes to Jail ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25029569,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 81,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Crime              Family',
#   'top_director': 'Charlie Cohen',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Little Man Tate ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25010896,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 99,
#   'distributor': 'Orion Pictures',
#   'genre': 'Drama',
#   'top_director': 'Scott Frank',
#   'top_actor': 'Jodie Foster'},
#  {'title': 'Invasion of the Body Snatchers ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24946533,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'United Artists',
#   'genre': 'Horror              Sci-Fi',
#   'top_director': 'W.D. Richter',
#   'top_actor': 'Donald Sutherland'},
#  {'title': 'From Russia with Love ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24796765,
#   'worldwide_gross_pay': 24808767,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'United Artists',
#   'genre': 'Action              Adventure              Thriller',
#   'top_director': 'Richard Maibaum',
#   'top_actor': 'Sean Connery'},
#  {'title': 'Waking Ned Devine ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24792251,
#   'worldwide_gross_pay': 55257450,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Fox Searchlight Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Kirk Jones',
#   'top_actor': 'Ian Bannen'},
#  {'title': 'Ghost Dad ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24707633,
#   'worldwide_gross_pay': 25421633,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 83,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy',
#   'top_director': 'Brent Maddock',
#   'top_actor': 'Bill Cosby'},
#  {'title': 'Leap! ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24702560,
#   'worldwide_gross_pay': 106127278,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Entertainment One',
#   'genre': 'Adventure              Animation              Comedy              Family              Music',
#   'top_director': 'Éric Warin',
#   'top_actor': 'Elle Fanning'},
#  {'title': 'Summer Rental ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24689703,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 87,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Jeremy Stevens',
#   'top_actor': 'John Candy'},
#  {'title': 'Operation Dumbo Drop ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24670346,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Adventure              Comedy              Drama              Family              War',
#   'top_director': 'James Morris',
#   'top_actor': 'Danny Glover'},
#  {'title': 'Lucky Lady ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24441725,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Crime              Drama',
#   'top_director': 'Willard Huyck',
#   'top_actor': 'Gene Hackman'},
#  {'title': 'The Spy Next Door ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24307086,
#   'worldwide_gross_pay': 66166000,
#   'budget': 28000000,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Lionsgate',
#   'genre': 'Action              Comedy              Family',
#   'top_director': 'Jonathan Bernstein',
#   'top_actor': 'Jackie Chan'},
#  {'title': 'Bronco Billy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24265659,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 116,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Comedy              Drama              Romance              Western',
#   'top_director': 'Dennis Hackin',
#   'top_actor': 'Clint Eastwood'},
#  {'title': 'An Inconvenient Truth ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24146161,
#   'worldwide_gross_pay': 49782012,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'Paramount Classics',
#   'genre': 'Documentary              News',
#   'top_director': 'Al Gore',
#   'top_actor': 'Al Gore'},
#  {'title': 'The Adventures of Huck Finn ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24103594,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Comedy              Drama              Family',
#   'top_director': 'Mark Twain',
#   'top_actor': 'Elijah Wood'},
#  {'title': 'Around the World in 80 Days ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24008137,
#   'worldwide_gross_pay': 72178895,
#   'budget': 110000000,
#   'lifetime_ranking': nan,
#   'running_time': nan,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Adventure              Comedy              Family              Western',
#   'top_director': 'Jules Verne',
#   'top_actor': 'Jackie Chan'},
#  {'title': 'Tom and Huck ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23920048,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 97,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Comedy              Drama              Family              Romance              Western',
#   'top_director': 'Mark Twain',
#   'top_actor': 'Jonathan Taylor'},
#  {'title': 'Santa Claus: The Movie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23717291,
#   'worldwide_gross_pay': nan,
#   'budget': 50000000,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Adventure              Family              Fantasy',
#   'top_director': 'David Newman',
#   'top_actor': 'Dudley Moore'},
#  {'title': 'Good Burger ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23712993,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Family',
#   'top_director': 'Dan Schneider',
#   'top_actor': 'Kel Mitchell'},
#  {'title': 'Sixteen Candles ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23686027,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'John Hughes',
#   'top_actor': 'Molly Ringwald'},
#  {'title': 'Two of a Kind ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23646952,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Fantasy              Romance',
#   'top_director': 'John Herzfeld',
#   'top_actor': 'John Travolta'},
#  {'title': 'Agent Cody Banks 2: Destination London ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23630159,
#   'worldwide_gross_pay': 28818995,
#   'budget': 26000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Action              Adventure              Comedy              Family              Romance              Sci-Fi',
#   'top_director': 'Jeffrey Jurgensen',
#   'top_actor': 'Frankie Muniz'},
#  {'title': 'Oscar ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23562716,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Crime',
#   'top_director': 'Claude Magnier',
#   'top_actor': 'Sylvester Stallone'},
#  {'title': 'Ernest Goes to Camp ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23509382,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 92,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family',
#   'top_director': 'John R.',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Benny & Joon ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23261580,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Barry Berman',
#   'top_actor': 'Johnny Depp'},
#  {'title': 'Kingdom Come ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23249649,
#   'worldwide_gross_pay': 23396049,
#   'budget': 7000000,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Fox Searchlight Pictures',
#   'genre': 'Comedy              Drama',
#   'top_director': 'David Dean',
#   'top_actor': 'LL Cool'},
#  {'title': 'The Remains of the Day ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23237911,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Drama              Romance',
#   'top_director': 'Kazuo Ishiguro',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'Monte Carlo ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23186769,
#   'worldwide_gross_pay': 39782683,
#   'budget': 20000000,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Comedy              Family              Romance',
#   'top_director': 'Thomas Bezucha',
#   'top_actor': 'Selena Gomez'},
#  {'title': 'The Iron Giant ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23159305,
#   'worldwide_gross_pay': 23180087,
#   'budget': 70000000,
#   'lifetime_ranking': nan,
#   'running_time': 86,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Animation              Comedy              Drama              Family              Sci-Fi',
#   'top_director': 'Tim McCanlies',
#   'top_actor': 'Eli Marienthal'},
#  {'title': 'Air Bud ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23144499,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'Kevin DiCicco',
#   'top_actor': 'Michael Jeter'},
#  {'title': 'D3: The Mighty Ducks ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 22955097,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
# ...
#   'domestic_gross_pay': 1083486,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Biography              Drama              Romance',
#   'top_director': 'Helene Hanff',
#   'top_actor': 'Anne Bancroft'},
#  {'title': 'Housekeeping ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1083282,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 116,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Comedy              Drama',
#   'top_director': 'Marilynne Robinson',
#   'top_actor': 'Christine Lahti'},
#  {'title': 'The Tango Lesson ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1080192,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Drama              Music              Romance',
#   'top_director': 'Sally Potter',
#   'top_actor': 'Sally Potter'},
#  {'title': 'Wonderstruck ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1060377,
#   'worldwide_gross_pay': 3285916,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 116,
#   'distributor': 'Roadside Attractions',
#   'genre': 'Adventure              Drama              Mystery',
#   'top_director': 'Brian Selznick',
#   'top_actor': 'Oakes Fegley'},
#  {'title': 'Comfort and Joy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1057368,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Bill Forsyth',
#   'top_actor': 'Bill Paterson'},
#  {'title': 'Caramel ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1055580,
#   'worldwide_gross_pay': 14248749,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Roadside Attractions',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Nadine Labaki',
#   'top_actor': 'Nadine Labaki'},
#  {'title': 'Extremedays ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1047553,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Providence Entertainment',
#   'genre': 'Action              Adventure              Comedy              Drama              Romance              Sport',
#   'top_director': 'Eric Hannah',
#   'top_actor': 'Dante Basco'},
#  {'title': 'The Perfect Game ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1037071,
#   'worldwide_gross_pay': 3878993,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'IndustryWorks Pictures',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'W. William',
#   'top_actor': 'Clifton Collins'},
#  {'title': 'Dark Horse ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1030851,
#   'worldwide_gross_pay': 1034197,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 85,
#   'distributor': 'Mongrel Media',
#   'genre': 'Documentary              Drama',
#   'top_director': 'Louise Osmond',
#   'top_actor': 'Jan Vokes'},
#  {'title': 'Nothing to Lose ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1016188,
#   'worldwide_gross_pay': 36075317,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Swen Releasing',
#   'genre': 'Biography              Drama',
#   'top_director': 'Stephen P.',
#   'top_actor': 'Petrônio Gontijo'},
#  {'title': 'Yu-Gi-Oh!: The Dark Side of Dimensions ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1015339,
#   'worldwide_gross_pay': 7445186,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 130,
#   'distributor': 'Screenvision',
#   'genre': 'Adventure              Animation              Drama              Fantasy',
#   'top_director': 'Kazuki Takahashi',
#   'top_actor': 'Shunsuke Kazama'},
#  {'title': 'Shiloh ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1007822,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Legacy',
#   'genre': 'Drama              Family',
#   'top_director': 'Phyllis Reynolds',
#   'top_actor': 'Blake Heron'},
#  {'title': 'From Up on Poppy Hill ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1002895,
#   'worldwide_gross_pay': 61487846,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'GKIDS',
#   'genre': 'Animation              Drama              Family              Romance',
#   'top_director': 'Tetsurô Sayama',
#   'top_actor': 'Sarah Bolger'},
#  {'title': 'March or Die ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1000000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Adventure              Drama              Romance              War',
#   'top_director': 'David Zelag',
#   'top_actor': 'Gene Hackman'},
#  {'title': 'Campus Man ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 989528,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Matt Dorff',
#   'top_actor': 'John Dye'},
#  {'title': 'Million Dollar Mystery ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 989033,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'De Laurentiis Entertainment Group (DEG)',
#   'genre': 'Comedy              Mystery',
#   'top_director': 'Tim Metcalfe',
#   'top_actor': 'Eddie Deezen'},
#  {'title': "Meek's Cutoff ",
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 977772,
#   'worldwide_gross_pay': 1205257,
#   'budget': 2000000,
#   'lifetime_ranking': nan,
#   'running_time': 104,
#   'distributor': 'Oscilloscope',
#   'genre': 'Adventure              Drama              Thriller              Western',
#   'top_director': 'Jonathan Raymond',
#   'top_actor': 'Michelle Williams'},
#  {'title': 'The Tale of The Princess Kaguya ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 974913,
#   'worldwide_gross_pay': 24706166,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 137,
#   'distributor': 'GKIDS',
#   'genre': 'Adventure              Animation              Drama              Family              Fantasy',
#   'top_director': 'Isao Takahata',
#   'top_actor': 'Chloë Grace'},
#  {'title': 'Appointment with Death ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 960040,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 102,
#   'distributor': 'Cannon Film Distributors',
#   'genre': 'Crime              Drama              Mystery              Thriller',
#   'top_director': 'Agatha Christie',
#   'top_actor': 'Peter Ustinov'},
#  {'title': 'The Fighting Preacher ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 954641,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Purdie Distribution',
#   'genre': 'Comedy              Drama              History',
#   'top_director': 'T.C. Christensen',
#   'top_actor': 'David McConnell'},
#  {'title': 'Faces Places ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 953717,
#   'worldwide_gross_pay': 3996577,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Cohen Media Group',
#   'genre': 'Documentary',
#   'top_director': 'Cast information',
#   'top_actor': 'Agnès Varda'},
#  {'title': 'The Ten Commandments ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 952820,
#   'worldwide_gross_pay': 1051907,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Rocky Mountain Pictures',
#   'genre': 'Animation              Family',
#   'top_director': 'John Stronach',
#   'top_actor': 'Ben Kingsley'},
#  {'title': 'More Than a Game ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 950675,
#   'worldwide_gross_pay': 960387,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Lionsgate',
#   'genre': 'Biography              Documentary              Sport',
#   'top_director': 'Kristopher Belman',
#   'top_actor': 'LeBron James'},
#  {'title': 'Children of Heaven ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 933933,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Miramax',
#   'genre': 'Drama              Family              Sport',
#   'top_director': 'Majid Majidi',
#   'top_actor': 'Mohammad Amir'},
#  {'title': 'An Egg Rescue ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 926514,
#   'worldwide_gross_pay': 3349309,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Pantelion Films',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'Rodolfo Riva',
#   'top_actor': 'Marcelo Barcelo'},
#  {'title': 'The Red Turtle ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 921974,
#   'worldwide_gross_pay': 6591789,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 80,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Animation              Family              Fantasy',
#   'top_director': 'Michael Dudok',
#   'top_actor': 'Emmanuel Garijo'},
#  {'title': 'Boruto: Naruto The Movie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 919651,
#   'worldwide_gross_pay': 38362448,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Eleven Arts',
#   'genre': 'Action              Adventure              Animation              Comedy',
#   'top_director': 'Toshiyuki Tsuru',
#   'top_actor': 'Yûko Sanpei'},
#  {'title': 'Brain Donors ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 918239,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 80,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Pat Proft',
#   'top_actor': 'John Turturro'},
#  {'title': 'Lagaan: Once Upon a Time in India ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 909043,
#   'worldwide_gross_pay': 1724806,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 224,
#   'distributor': 'Set Pictures',
#   'genre': 'Drama              Musical              Sport',
#   'top_director': 'Ashutosh Gowariker',
#   'top_actor': 'Aamir Khan'},
#  {'title': 'The War Room ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 901668,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'October Films',
#   'genre': 'Documentary              History',
#   'top_director': 'D.A. Pennebaker',
#   'top_actor': 'James Carville'},
#  {'title': 'The Wildest Dream ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 898137,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'National Geographic Entertainment',
#   'genre': 'Biography              Documentary',
#   'top_director': 'Mark MacKenzie',
#   'top_actor': 'Conrad Anker'},
#  {'title': 'The Glass Menagerie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 895904,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Cineplex Odeon Films',
#   'genre': 'Drama',
#   'top_director': 'Tennessee Williams',
#   'top_actor': 'Joanne Woodward'},
#  {'title': 'Believe ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 890303,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 119,
#   'distributor': 'Freestyle Releasing',
#   'genre': 'Drama',
#   'top_director': 'Billy Dickson',
#   'top_actor': "Ryan O'Quinn"},
#  {'title': 'Saawariya ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 885574,
#   'worldwide_gross_pay': 18525631,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 142,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Drama              Musical              Romance',
#   'top_director': 'Fyodor Dostoevsky',
#   'top_actor': 'Ranbir Kapoor'},
#  {'title': 'Princess Kaiulani ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 883887,
#   'worldwide_gross_pay': nan,
#   'budget': 9000000,
#   'lifetime_ranking': nan,
#   'running_time': 130,
#   'distributor': 'Roadside Attractions',
#   'genre': 'Biography              Drama              History              Romance',
#   'top_director': 'Marc Forby',
#   'top_actor': "Q'orianka Kilcher"},
#  {'title': 'Emma Smith: My Story ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 881787,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Candlelight Media Group',
#   'genre': 'Biography              Drama              History',
#   'top_director': 'T.C. Christensen',
#   'top_actor': 'Patricia Place'},
#  {'title': 'Fast, Cheap & Out of Control ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 878960,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 80,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Documentary',
#   'top_director': 'Errol Morris',
#   'top_actor': 'Dave Hoover'},
#  {'title': 'Duma ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 870067,
#   'worldwide_gross_pay': 994790,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'Carol Cawthra',
#   'top_actor': 'Alex Michaeletos'},
#  {'title': 'Mirrormask ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 866999,
#   'worldwide_gross_pay': nan,
#   'budget': 4000000,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'IDP Distribution',
#   'genre': 'Adventure              Fantasy',
#   'top_director': 'Neil Gaiman',
#   'top_actor': 'Stephanie Leonidas'},
#  {'title': 'Sarah Landon and the Paranormal Hour ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 858415,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 81,
#   'distributor': 'Freestyle Releasing',
#   'genre': 'Action              Adventure              Family              Fantasy              Horror              Mystery              Thriller',
#   'top_director': 'John Comrie',
#   'top_actor': 'Rissa Walters'},
#  {'title': 'Song of the Sea ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 857522,
#   'worldwide_gross_pay': 4190884,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'GKIDS',
#   'genre': 'Adventure              Animation              Drama              Family              Fantasy',
#   'top_director': 'Will Collins',
#   'top_actor': 'David Rawle'},
#  None,
#  {'title': 'Sharkwater ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 850920,
#   'worldwide_gross_pay': 1658393,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Freestyle Releasing',
#   'genre': 'Documentary',
#   'top_director': 'Rob Stewart',
#   'top_actor': 'Rob Stewart'},
#  {'title': 'Scoob! ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 850000,
#   'worldwide_gross_pay': 25750000,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Animation              Comedy              Crime              Family              Fantasy              Mystery              Sci-Fi',
#   'top_director': 'Adam Sztykiel',
#   'top_actor': 'Will Forte'},
#  {'title': 'Guadalupe: El Milagro Y El Mensaje ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 848139,
#   'worldwide_gross_pay': 1499149,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Slowhand Cinema Releasing',
#   'genre': 'Drama              Family              Fantasy              Mystery',
#   'top_director': 'Tessie Gutierrez',
#   'top_actor': 'José Carlos'},
#  {'title': 'Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 840958,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Cinecom Pictures',
#   'genre': 'Comedy              Drama',
#   'top_director': 'Ed Graczyk',
#   'top_actor': 'Cher SissySee'}]

# %%
#movies_page_info_dict=[]
movies_page_info_dict = list(filter(None,movies_page_info_list))
movies_page_info_dict
# Out:
# [{'title': 'See Spot Run ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33357476,
#   'worldwide_gross_pay': 43057552,
#   'budget': 35000000,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Comedy              Crime              Family',
#   'top_director': 'George Gallo',
#   'top_actor': 'David Arquette'},
#  {'title': 'Teen Wolf ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33086611,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Atlantic Releasing Corporation',
#   'genre': 'Comedy              Fantasy              Romance',
#   'top_director': 'Jeph Loeb',
#   'top_actor': 'Michael J.'},
#  {'title': 'The Second Best Exotic Marigold Hotel ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33078266,
#   'worldwide_gross_pay': 85978292,
#   'budget': 10000000,
#   'lifetime_ranking': nan,
#   'running_time': 122,
#   'distributor': 'Fox Searchlight Pictures',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Ol Parker',
#   'top_actor': 'Judi Dench'},
#  {'title': 'Tron ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 33000000,
#   'worldwide_gross_pay': 33000525,
#   'budget': 17000000,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Adventure              Sci-Fi',
#   'top_director': 'Steven Lisberger',
#   'top_actor': 'Jeff Bridges'},
#  {'title': 'The Sandlot ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32950136,
#   'worldwide_gross_pay': 34348443,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'David Mickey',
#   'top_actor': 'Tom Guiry'},
#  {'title': '*batteries not included ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32945797,
#   'worldwide_gross_pay': 65088797,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy              Sci-Fi',
#   'top_director': 'Mick Garris',
#   'top_actor': 'Hume Cronyn'},
#  {'title': 'Dreamer ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32751093,
#   'worldwide_gross_pay': 38741732,
#   'budget': 32000000,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'DreamWorks Distribution',
#   'genre': 'Drama              Family              Sport',
#   'top_director': 'John Gatins',
#   'top_actor': 'Kurt Russell'},
#  {'title': 'Return to Me ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32722798,
#   'worldwide_gross_pay': 36609995,
#   'budget': 24000000,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Bonnie Hunt',
#   'top_actor': 'David Duchovny'},
#  {'title': 'Because of Winn-Dixie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32647042,
#   'worldwide_gross_pay': 33589427,
#   'budget': 14000000,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Family',
#   'top_director': 'Kate DiCamillo',
#   'top_actor': 'AnnaSophia Robb'},
#  {'title': 'The Accidental Tourist ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32632093,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 121,
#   'distributor': 'Warner Bros.',
#   'genre': 'Drama              Romance',
#   'top_director': 'Anne Tyler',
#   'top_actor': 'William Hurt'},
#  {'title': 'October Sky ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32570685,
#   'worldwide_gross_pay': 34698753,
#   'budget': 25000000,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Universal Pictures',
#   'genre': 'Biography              Drama              Family',
#   'top_director': 'Homer H.',
#   'top_actor': 'Jake Gyllenhaal'},
#  {'title': 'Nothing in Common ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32324557,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Garry Marshall',
#   'top_actor': 'Tom Hanks'},
#  {'title': 'The Age of Innocence ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32255440,
#   'worldwide_gross_pay': nan,
#   'budget': 34000000,
#   'lifetime_ranking': nan,
#   'running_time': 139,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Drama              Romance',
#   'top_director': 'Edith Wharton',
#   'top_actor': 'Daniel Day-Lewis'},
#  {'title': 'The Bad News Bears ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 32211330,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 102,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'Bill Lancaster',
#   'top_actor': 'Walter Matthau'},
#  {'title': 'The Outlaw Josey Wales ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31800000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 135,
#   'distributor': 'Warner Bros.',
#   'genre': 'Western',
#   'top_director': 'Forrest Carter',
#   'top_actor': 'Clint Eastwood'},
#  {'title': '1941 ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31755742,
#   'worldwide_gross_pay': 92455742,
#   'budget': 35000000,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Comedy              War',
#   'top_director': 'Robert Zemeckis',
#   'top_actor': 'John Belushi'},
#  {'title': 'The Bear ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31753898,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'James Oliver',
#   'top_actor': 'Tchéky Karyo'},
#  {'title': 'August Rush ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31664162,
#   'worldwide_gross_pay': 66122026,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 114,
#   'distributor': 'Warner Bros.',
#   'genre': 'Drama              Music',
#   'top_director': 'Nick Castle',
#   'top_actor': 'Freddie Highmore'},
#  {'title': 'Good Night, and Good Luck. ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31558003,
#   'worldwide_gross_pay': 54641191,
#   'budget': 7000000,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Warner Independent Pictures (WIP)',
#   'genre': 'Biography              Drama              History',
#   'top_director': 'George Clooney',
#   'top_actor': 'David Strathairn'},
#  {'title': 'High Anxiety ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31063038,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Mystery              Thriller',
#   'top_director': 'Mel Brooks',
#   'top_actor': 'Mel Brooks'},
#  {'title': 'The Pirates! Band of Misfits ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31051126,
#   'worldwide_gross_pay': 123054041,
#   'budget': 55000000,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Adventure              Animation              Comedy              Family',
#   'top_director': 'Jeff Newitt',
#   'top_actor': 'Hugh Grant'},
#  {'title': 'Conan the Destroyer ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 31042035,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 103,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Fantasy',
#   'top_director': 'Robert E.',
#   'top_actor': 'Arnold Schwarzenegger'},
#  {'title': 'Home Alone 3 ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30882515,
#   'worldwide_gross_pay': 79082515,
#   'budget': 32000000,
#   'lifetime_ranking': nan,
#   'running_time': 102,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Action              Comedy              Crime              Family',
#   'top_director': 'John Hughes',
#   'top_actor': 'Alex D.'},
#  {'title': 'The Princess Bride ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30857814,
#   'worldwide_gross_pay': 30902442,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Family              Fantasy              Romance',
#   'top_director': 'William Goldman',
#   'top_actor': 'Cary Elwes'},
#  {'title': 'I Love Trouble ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30806194,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 123,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Comedy              Romance              Thriller',
#   'top_director': 'Nancy Meyers',
#   'top_actor': 'Nick Nolte'},
#  {'title': 'Dragon Ball Super: Broly ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30712119,
#   'worldwide_gross_pay': 115757940,
#   'budget': 8500000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'FUNimation Entertainment',
#   'genre': 'Action              Adventure              Animation              Family              Fantasy              Sci-Fi',
#   'top_director': 'Akira Toriyama',
#   'top_actor': 'Masako Nozawa'},
#  {'title': 'Major League II ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30626182,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Sport',
#   'top_director': 'David S.',
#   'top_actor': 'Charlie Sheen'},
#  {'title': 'Blank Check ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30577969,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Crime              Family',
#   'top_director': 'Blake Snyder',
#   'top_actor': 'Brian Bonsall'},
#  {'title': 'The Lord of the Rings ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30471420,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 132,
#   'distributor': 'United Artists',
#   'genre': 'Adventure              Animation              Fantasy',
#   'top_director': 'Chris Conkling',
#   'top_actor': 'Christopher Guard'},
#  {'title': 'The Champ ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30441738,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 121,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Drama              Sport',
#   'top_director': 'Frances Marion',
#   'top_actor': 'Jon Voight'},
#  {'title': 'Sgt. Bilko ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30356793,
#   'worldwide_gross_pay': 37956793,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Nat Hiken',
#   'top_actor': 'Steve Martin'},
#  {'title': 'Being There ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30177511,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 130,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama',
#   'top_director': 'Jerzy Kosinski',
#   'top_actor': 'Peter Sellers'},
#  {'title': 'When the Game Stands Tall ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30127963,
#   'worldwide_gross_pay': 30138754,
#   'budget': 15000000,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Biography              Drama              Family              Sport',
#   'top_director': 'Scott Marshall',
#   'top_actor': 'Jim Caviezel'},
#  {'title': 'Free Willy 2: The Adventure Home ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30077111,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'Keith Walker',
#   'top_actor': 'Jason James'},
#  {'title': 'The Gods Must Be Crazy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 30031783,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Comedy',
#   'top_director': 'Jamie Uys',
#   'top_actor': 'N!xau XiSee'},
#  {'title': 'Madeline ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29967750,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Comedy              Family',
#   'top_director': 'Ludwig Bemelmans',
#   'top_actor': 'Frances McDormand'},
#  {'title': 'Teen Titans GO! To the Movies ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29790236,
#   'worldwide_gross_pay': 52090236,
#   'budget': 10000000,
#   'lifetime_ranking': nan,
#   'running_time': 84,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Animation              Comedy              Family              Fantasy              Musical              Sci-Fi',
#   'top_director': 'Peter Rida',
#   'top_actor': 'Greg Cipes'},
#  {'title': 'Harry and the Hendersons ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29760613,
#   'worldwide_gross_pay': 49998613,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 110,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy',
#   'top_director': 'William Dear',
#   'top_actor': 'John Lithgow'},
#  {'title': 'Never Cry Wolf ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29600000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Drama',
#   'top_director': 'Farley Mowat',
#   'top_actor': 'Charles Martin'},
#  {'title': 'Twilight Zone: The Movie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29450919,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Warner Bros.',
#   'genre': 'Horror              Sci-Fi',
#   'top_director': 'John Landis',
#   'top_actor': 'Dan Aykroyd'},
#  {'title': 'Spice World ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29342592,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Comedy              Family              Music',
#   'top_director': 'Spice Girls',
#   'top_actor': 'Mel B'},
#  {'title': 'Confessions of a Teenage Drama Queen ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29331068,
#   'worldwide_gross_pay': 33251890,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family              Music              Romance',
#   'top_director': 'Dyan Sheldon',
#   'top_actor': 'Lindsay Lohan'},
#  {'title': 'Zathura: A Space Adventure ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29258869,
#   'worldwide_gross_pay': 65079104,
#   'budget': 65000000,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Action              Adventure              Comedy              Family              Fantasy              Sci-Fi',
#   'top_director': 'Chris Van',
#   'top_actor': 'Josh Hutcherson'},
#  {'title': 'Nanny McPhee Returns ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29011215,
#   'worldwide_gross_pay': 93251121,
#   'budget': 35000000,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy              War',
#   'top_director': 'Emma Thompson',
#   'top_actor': 'Emma Thompson'},
#  {'title': '3 Ninjas ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 29000301,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 84,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Comedy              Family              Sport',
#   'top_director': 'Kenny Kim',
#   'top_actor': 'Victor Wong'},
#  {'title': 'James and the Giant Peach ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28946127,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 79,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Animation              Family              Fantasy              Musical',
#   'top_director': 'Roald Dahl',
#   'top_actor': 'Paul Terry'},
#  {'title': 'In the Army Now ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28881266,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              War',
#   'top_director': 'Steve Zacharias',
#   'top_actor': 'Genre keyword'},
#  {'title': 'One Direction: This Is Us ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28873374,
#   'worldwide_gross_pay': 68567841,
#   'budget': 10000000,
#   'lifetime_ranking': nan,
#   'running_time': 92,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Documentary              Music',
#   'top_director': 'Simon Cowell',
#   'top_actor': 'Liam Payne'},
#  {'title': 'Starman ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28744356,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Romance              Sci-Fi',
#   'top_director': 'Bruce A.',
#   'top_actor': 'Jeff Bridges'},
#  {'title': 'The Last Starfighter ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28733290,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Sci-Fi',
#   'top_director': 'Jonathan R.',
#   'top_actor': 'Lance Guest'},
#  {'title': 'Hoosiers ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28607524,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 114,
#   'distributor': 'Orion Pictures',
#   'genre': 'Drama              Sport',
#   'top_director': 'Angelo Pizzo',
#   'top_actor': 'Gene Hackman'},
#  {'title': 'House Calls ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28460702,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Max Shulman',
#   'top_actor': 'Walter Matthau'},
#  {'title': 'High Road to China ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28445927,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Drama              Romance              War',
#   'top_director': 'Jon Cleary',
#   'top_actor': 'Tom Selleck'},
#  {'title': 'The Crocodile Hunter: Collision Course ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28442574,
#   'worldwide_gross_pay': 33082548,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Action              Adventure              Comedy              Family',
#   'top_director': 'John Stainton',
#   'top_actor': 'Steve Irwin'},
#  {'title': 'Garfield: A Tail of Two Kitties ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28426747,
#   'worldwide_gross_pay': 143325970,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 82,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Animation              Comedy              Family',
#   'top_director': 'Steven Rimdzius',
#   'top_actor': 'Genre keyword'},
#  {'title': 'The Nut Job 2: Nutty by Nature ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28370522,
#   'worldwide_gross_pay': 68743485,
#   'budget': 40000000,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Open Road Films (II)',
#   'genre': 'Adventure              Animation              Comedy              Crime              Family',
#   'top_director': 'Scott Bindley',
#   'top_actor': 'Will Arnett'},
#  {'title': 'Victor Victoria ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28215453,
#   'worldwide_gross_pay': 28229046,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Music              Romance',
#   'top_director': 'Blake Edwards',
#   'top_actor': 'Julie Andrews'},
#  {'title': 'Ernest Saves Christmas ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28202109,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family              Fantasy',
#   'top_director': 'Ed Turner',
#   'top_actor': 'Genre keyword'},
#  {'title': 'The Prince and Me ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28176497,
#   'worldwide_gross_pay': 37666766,
#   'budget': 22000000,
#   'lifetime_ranking': nan,
#   'running_time': 111,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Family              Romance',
#   'top_director': 'Mark Amin',
#   'top_actor': 'Julia Stiles'},
#  {'title': 'The Ant Bully ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28142535,
#   'worldwide_gross_pay': 55181129,
#   'budget': 50000000,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'John A.',
#   'top_actor': 'Paul Giamatti'},
#  {'title': 'Johnny English ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28082366,
#   'worldwide_gross_pay': 160466000,
#   'budget': 40000000,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Comedy',
#   'top_director': 'Neal Purvis',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Cannonball Run II ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28078073,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Comedy',
#   'top_director': 'Ralph Bakshi',
#   'top_actor': 'Burt Reynolds'},
#  {'title': 'Police Academy 4: Citizens on Patrol ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 28061343,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Crime',
#   'top_director': 'Neal Israel',
#   'top_actor': 'Genre keyword'},
#  {'title': 'The Majestic ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27807266,
#   'worldwide_gross_pay': 37317673,
#   'budget': 72000000,
#   'lifetime_ranking': nan,
#   'running_time': 152,
#   'distributor': 'Warner Bros.',
#   'genre': 'Drama              Romance',
#   'top_director': 'Michael Sloane',
#   'top_actor': 'Jim Carrey'},
#  {'title': 'Murder on the Orient Express ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27634716,
#   'worldwide_gross_pay': 27659517,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 128,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Crime              Drama              Mystery',
#   'top_director': 'Paul Dehn',
#   'top_actor': 'Albert Finney'},
#  {'title': 'Baby Geniuses ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27250736,
#   'worldwide_gross_pay': 36450736,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 97,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Comedy              Crime              Family              Sci-Fi',
#   'top_director': 'Steven Paul',
#   'top_actor': 'Kathleen Turner'},
#  {'title': 'The Bridge on the River Kwai ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27200000,
#   'worldwide_gross_pay': nan,
#   'budget': 3000000,
#   'lifetime_ranking': nan,
#   'running_time': 161,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Adventure              Drama              War',
#   'top_director': 'Pierre Boulle',
#   'top_actor': 'William Holden'},
#  {'title': 'A Passage to India ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27187653,
#   'worldwide_gross_pay': 27201487,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 164,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Adventure              Drama              History',
#   'top_director': 'E.M. Forster',
#   'top_actor': 'Judy Davis'},
#  {'title': 'Cats ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27166770,
#   'worldwide_gross_pay': 73833415,
#   'budget': 95000000,
#   'lifetime_ranking': nan,
#   'running_time': 110,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Drama              Family              Fantasy              Musical',
#   'top_director': 'Lee Hall',
#   'top_actor': 'James Corden'},
#  {'title': 'Airplane II: The Sequel ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27150534,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 85,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Sci-Fi',
#   'top_director': 'Ken Finkleman',
#   'top_actor': 'Robert Hays'},
#  {'title': 'The Jazz Singer ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27118000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'Universal Pictures',
#   'genre': 'Drama              Music              Romance',
#   'top_director': 'Sidney J.',
#   'top_actor': 'Laurence Olivier'},
#  {'title': 'Flash Gordon ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 27107960,
#   'worldwide_gross_pay': 27181317,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 111,
#   'distributor': 'Universal Pictures',
#   'genre': 'Action              Adventure              Sci-Fi',
#   'top_director': 'Lorenzo Semple',
#   'top_actor': 'Sam J.'},
#  {'title': 'Paulie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26875268,
#   'worldwide_gross_pay': nan,
#   'budget': 23000000,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'DreamWorks Distribution',
#   'genre': 'Adventure              Comedy              Drama              Family',
#   'top_director': 'Laurie Craig',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Going in Style ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26869286,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 97,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Crime              Drama',
#   'top_director': 'Martin Brest',
#   'top_actor': 'George Burns'},
#  {'title': 'Overboard ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26713187,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 112,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Leslie Dixon',
#   'top_actor': 'Goldie Hawn'},
#  {'title': 'Baby Boom ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26712476,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 110,
#   'distributor': 'United Artists',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Nancy Meyers',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Harriet the Spy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26570048,
#   'worldwide_gross_pay': nan,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Drama              Family',
#   'top_director': 'Louise Fitzhugh',
#   'top_actor': 'Michelle Trachtenberg'},
#  {'title': 'First Kid ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26491793,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family',
#   'top_director': 'Tim Kelleher',
#   'top_actor': 'Sinbad Sam'},
#  {'title': 'Sinbad: Legend of the Seven Seas ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26483452,
#   'worldwide_gross_pay': 80773077,
#   'budget': 60000000,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'DreamWorks Distribution',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'Tim Johnson',
#   'top_actor': 'Brad Pitt'},
#  {'title': 'The Art of Racing in the Rain ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26395642,
#   'worldwide_gross_pay': 33766787,
#   'budget': 18000000,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Romance              Sport',
#   'top_director': 'Mark Bomback',
#   'top_actor': 'Kevin Costner'},
#  {'title': 'I.Q. ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26381221,
#   'worldwide_gross_pay': nan,
#   'budget': 25000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Andy Breckman',
#   'top_actor': 'Tim Robbins'},
#  {'title': 'Houseguest ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26325256,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 113,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Michael J.',
#   'top_actor': 'Sinbad Kevin'},
#  {'title': 'Protocol ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26186631,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy',
#   'top_director': 'Buck Henry',
#   'top_actor': 'Goldie Hawn'},
#  {'title': 'Modern Problems ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26154211,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Fantasy              Sci-Fi',
#   'top_director': 'Ken Shapiro',
#   'top_actor': 'Chevy Chase'},
#  {'title': 'Howards End ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26126837,
#   'worldwide_gross_pay': 26341736,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 142,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Drama              Romance',
#   'top_director': 'E.M. Forster',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'The Elephant Man ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26010864,
#   'worldwide_gross_pay': 26023706,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 124,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Biography              Drama',
#   'top_director': 'Christopher De',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'The Adventures of Rocky & Bullwinkle ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 26005820,
#   'worldwide_gross_pay': 35134820,
#   'budget': 76000000,
#   'lifetime_ranking': nan,
#   'running_time': 92,
#   'distributor': 'Universal Pictures',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'Jay Ward',
#   'top_actor': 'Robert De'},
#  {'title': 'The Turning Point ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25933445,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 119,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Drama              Romance',
#   'top_director': 'Arthur Laurents',
#   'top_actor': 'Anne Bancroft'},
#  {'title': 'Leap Year ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25918920,
#   'worldwide_gross_pay': 32686500,
#   'budget': 19000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Deborah Kaplan',
#   'top_actor': 'Amy Adams'},
#  {'title': 'Innerspace ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25893810,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': nan,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Comedy              Sci-Fi              Thriller',
#   'top_director': 'Chip Proser',
#   'top_actor': 'Dennis Quaid'},
#  {'title': 'That Thing You Do! ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25857416,
#   'worldwide_gross_pay': 34585416,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Drama              Music',
#   'top_director': 'Tom Hanks',
#   'top_actor': 'Tom Hanks'},
#  {'title': 'Shadowlands ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25842377,
#   'worldwide_gross_pay': nan,
#   'budget': 22000000,
#   'lifetime_ranking': nan,
#   'running_time': 131,
#   'distributor': 'Savoy Pictures',
#   'genre': 'Biography              Drama              Romance',
#   'top_director': 'William Nicholson',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'You Again ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25702053,
#   'worldwide_gross_pay': 32054369,
#   'budget': 20000000,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Moe Jelline',
#   'top_actor': 'Kristen Bell'},
#  {'title': 'The Outsiders ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25697647,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Warner Bros.',
#   'genre': 'Crime              Drama',
#   'top_director': 'Kathleen Rowell',
#   'top_actor': 'C. Thomas'},
#  {'title': 'Crocodile Dundee in Los Angeles ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25635682,
#   'worldwide_gross_pay': 39438674,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Action              Adventure              Comedy              Crime',
#   'top_director': 'Paul Hogan',
#   'top_actor': 'Paul Hogan'},
#  {'title': 'Nancy Drew ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25612520,
#   'worldwide_gross_pay': 30666930,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 99,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy              Crime              Family              Mystery              Romance              Thriller',
#   'top_director': 'Andrew Fleming',
#   'top_actor': 'Emma Roberts'},
#  {'title': 'Funny Farm ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25537221,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Warner Bros.',
#   'genre': 'Comedy',
#   'top_director': 'Jay Cronley',
#   'top_actor': 'Chevy Chase'},
#  {'title': 'My Father the Hero ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25479558,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'Gérard Lauzier',
#   'top_actor': 'Gérard Depardieu'},
#  {'title': 'Part of Me ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25326071,
#   'worldwide_gross_pay': 32726956,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Documentary              Music',
#   'top_director': 'Jane Lipsitz',
#   'top_actor': 'Katy Perry'},
#  {'title': 'Aliens in the Attic ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25200412,
#   'worldwide_gross_pay': 57881056,
#   'budget': 45000000,
#   'lifetime_ranking': nan,
#   'running_time': 86,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Comedy              Family              Fantasy              Sci-Fi',
#   'top_director': 'Mark Burton',
#   'top_actor': 'Ashley Tisdale'},
#  {'title': 'Fly Away Home ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25143818,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'Bill Lishman',
#   'top_actor': 'Jeff Daniels'},
#  {'title': 'Alpha and Omega ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25107267,
#   'worldwide_gross_pay': 50507267,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Lionsgate',
#   'genre': 'Adventure              Animation              Comedy              Family              Romance',
#   'top_director': 'Ben Gluck',
#   'top_actor': 'Hayden Panettiere'},
#  {'title': 'The Cutting Edge ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25105517,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama              Romance              Sport',
#   'top_director': 'Tony Gilroy',
#   'top_actor': 'D.B. Sweeney'},
#  {'title': 'Ernest Goes to Jail ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25029569,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 81,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Crime              Family',
#   'top_director': 'Charlie Cohen',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Little Man Tate ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 25010896,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 99,
#   'distributor': 'Orion Pictures',
#   'genre': 'Drama',
#   'top_director': 'Scott Frank',
#   'top_actor': 'Jodie Foster'},
#  {'title': 'Invasion of the Body Snatchers ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24946533,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'United Artists',
#   'genre': 'Horror              Sci-Fi',
#   'top_director': 'W.D. Richter',
#   'top_actor': 'Donald Sutherland'},
#  {'title': 'From Russia with Love ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24796765,
#   'worldwide_gross_pay': 24808767,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 115,
#   'distributor': 'United Artists',
#   'genre': 'Action              Adventure              Thriller',
#   'top_director': 'Richard Maibaum',
#   'top_actor': 'Sean Connery'},
#  {'title': 'Waking Ned Devine ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24792251,
#   'worldwide_gross_pay': 55257450,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'Fox Searchlight Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Kirk Jones',
#   'top_actor': 'Ian Bannen'},
#  {'title': 'Ghost Dad ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24707633,
#   'worldwide_gross_pay': 25421633,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 83,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Family              Fantasy',
#   'top_director': 'Brent Maddock',
#   'top_actor': 'Bill Cosby'},
#  {'title': 'Leap! ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24702560,
#   'worldwide_gross_pay': 106127278,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Entertainment One',
#   'genre': 'Adventure              Animation              Comedy              Family              Music',
#   'top_director': 'Éric Warin',
#   'top_actor': 'Elle Fanning'},
#  {'title': 'Summer Rental ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24689703,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 87,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Jeremy Stevens',
#   'top_actor': 'John Candy'},
#  {'title': 'Operation Dumbo Drop ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24670346,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Adventure              Comedy              Drama              Family              War',
#   'top_director': 'James Morris',
#   'top_actor': 'Danny Glover'},
#  {'title': 'Lucky Lady ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24441725,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Crime              Drama',
#   'top_director': 'Willard Huyck',
#   'top_actor': 'Gene Hackman'},
#  {'title': 'The Spy Next Door ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24307086,
#   'worldwide_gross_pay': 66166000,
#   'budget': 28000000,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Lionsgate',
#   'genre': 'Action              Comedy              Family',
#   'top_director': 'Jonathan Bernstein',
#   'top_actor': 'Jackie Chan'},
#  {'title': 'Bronco Billy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24265659,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 116,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Comedy              Drama              Romance              Western',
#   'top_director': 'Dennis Hackin',
#   'top_actor': 'Clint Eastwood'},
#  {'title': 'An Inconvenient Truth ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24146161,
#   'worldwide_gross_pay': 49782012,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'Paramount Classics',
#   'genre': 'Documentary              News',
#   'top_director': 'Al Gore',
#   'top_actor': 'Al Gore'},
#  {'title': 'The Adventures of Huck Finn ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24103594,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 108,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Comedy              Drama              Family',
#   'top_director': 'Mark Twain',
#   'top_actor': 'Elijah Wood'},
#  {'title': 'Around the World in 80 Days ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 24008137,
#   'worldwide_gross_pay': 72178895,
#   'budget': 110000000,
#   'lifetime_ranking': nan,
#   'running_time': nan,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Action              Adventure              Comedy              Family              Western',
#   'top_director': 'Jules Verne',
#   'top_actor': 'Jackie Chan'},
#  {'title': 'Tom and Huck ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23920048,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 97,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Adventure              Comedy              Drama              Family              Romance              Western',
#   'top_director': 'Mark Twain',
#   'top_actor': 'Jonathan Taylor'},
#  {'title': 'Santa Claus: The Movie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23717291,
#   'worldwide_gross_pay': nan,
#   'budget': 50000000,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'TriStar Pictures',
#   'genre': 'Adventure              Family              Fantasy',
#   'top_director': 'David Newman',
#   'top_actor': 'Dudley Moore'},
#  {'title': 'Good Burger ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23712993,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy              Family',
#   'top_director': 'Dan Schneider',
#   'top_actor': 'Kel Mitchell'},
#  {'title': 'Sixteen Candles ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23686027,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy              Romance',
#   'top_director': 'John Hughes',
#   'top_actor': 'Molly Ringwald'},
#  {'title': 'Two of a Kind ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23646952,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Comedy              Fantasy              Romance',
#   'top_director': 'John Herzfeld',
#   'top_actor': 'John Travolta'},
#  {'title': 'Agent Cody Banks 2: Destination London ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23630159,
#   'worldwide_gross_pay': 28818995,
#   'budget': 26000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Action              Adventure              Comedy              Family              Romance              Sci-Fi',
#   'top_director': 'Jeffrey Jurgensen',
#   'top_actor': 'Frankie Muniz'},
#  {'title': 'Oscar ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23562716,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Crime',
#   'top_director': 'Claude Magnier',
#   'top_actor': 'Sylvester Stallone'},
#  {'title': 'Ernest Goes to Camp ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23509382,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 92,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Family',
#   'top_director': 'John R.',
#   'top_actor': 'Genre keyword'},
#  {'title': 'Benny & Joon ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23261580,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Barry Berman',
#   'top_actor': 'Johnny Depp'},
#  {'title': 'Kingdom Come ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23249649,
#   'worldwide_gross_pay': 23396049,
#   'budget': 7000000,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Fox Searchlight Pictures',
#   'genre': 'Comedy              Drama',
#   'top_director': 'David Dean',
#   'top_actor': 'LL Cool'},
#  {'title': 'The Remains of the Day ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23237911,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Drama              Romance',
#   'top_director': 'Kazuo Ishiguro',
#   'top_actor': 'Anthony Hopkins'},
#  {'title': 'Monte Carlo ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23186769,
#   'worldwide_gross_pay': 39782683,
#   'budget': 20000000,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Twentieth Century Fox',
#   'genre': 'Adventure              Comedy              Family              Romance',
#   'top_director': 'Thomas Bezucha',
#   'top_actor': 'Selena Gomez'},
#  {'title': 'The Iron Giant ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23159305,
#   'worldwide_gross_pay': 23180087,
#   'budget': 70000000,
#   'lifetime_ranking': nan,
#   'running_time': 86,
#   'distributor': 'Warner Bros.',
#   'genre': 'Action              Adventure              Animation              Comedy              Drama              Family              Sci-Fi',
#   'top_director': 'Tim McCanlies',
#   'top_actor': 'Eli Marienthal'},
#  {'title': 'Air Bud ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 23144499,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'Kevin DiCicco',
#   'top_actor': 'Michael Jeter'},
#  {'title': 'D3: The Mighty Ducks ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 22955097,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
# ...
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1083486,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Biography              Drama              Romance',
#   'top_director': 'Helene Hanff',
#   'top_actor': 'Anne Bancroft'},
#  {'title': 'Housekeeping ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1083282,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 116,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Comedy              Drama',
#   'top_director': 'Marilynne Robinson',
#   'top_actor': 'Christine Lahti'},
#  {'title': 'The Tango Lesson ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1080192,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Drama              Music              Romance',
#   'top_director': 'Sally Potter',
#   'top_actor': 'Sally Potter'},
#  {'title': 'Wonderstruck ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1060377,
#   'worldwide_gross_pay': 3285916,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 116,
#   'distributor': 'Roadside Attractions',
#   'genre': 'Adventure              Drama              Mystery',
#   'top_director': 'Brian Selznick',
#   'top_actor': 'Oakes Fegley'},
#  {'title': 'Comfort and Joy ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1057368,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 106,
#   'distributor': 'Universal Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Bill Forsyth',
#   'top_actor': 'Bill Paterson'},
#  {'title': 'Caramel ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1055580,
#   'worldwide_gross_pay': 14248749,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Roadside Attractions',
#   'genre': 'Comedy              Drama              Romance',
#   'top_director': 'Nadine Labaki',
#   'top_actor': 'Nadine Labaki'},
#  {'title': 'Extremedays ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1047553,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Providence Entertainment',
#   'genre': 'Action              Adventure              Comedy              Drama              Romance              Sport',
#   'top_director': 'Eric Hannah',
#   'top_actor': 'Dante Basco'},
#  {'title': 'The Perfect Game ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1037071,
#   'worldwide_gross_pay': 3878993,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 118,
#   'distributor': 'IndustryWorks Pictures',
#   'genre': 'Comedy              Drama              Family              Sport',
#   'top_director': 'W. William',
#   'top_actor': 'Clifton Collins'},
#  {'title': 'Dark Horse ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1030851,
#   'worldwide_gross_pay': 1034197,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 85,
#   'distributor': 'Mongrel Media',
#   'genre': 'Documentary              Drama',
#   'top_director': 'Louise Osmond',
#   'top_actor': 'Jan Vokes'},
#  {'title': 'Nothing to Lose ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1016188,
#   'worldwide_gross_pay': 36075317,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Swen Releasing',
#   'genre': 'Biography              Drama',
#   'top_director': 'Stephen P.',
#   'top_actor': 'Petrônio Gontijo'},
#  {'title': 'Yu-Gi-Oh!: The Dark Side of Dimensions ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1015339,
#   'worldwide_gross_pay': 7445186,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 130,
#   'distributor': 'Screenvision',
#   'genre': 'Adventure              Animation              Drama              Fantasy',
#   'top_director': 'Kazuki Takahashi',
#   'top_actor': 'Shunsuke Kazama'},
#  {'title': 'Shiloh ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1007822,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Legacy',
#   'genre': 'Drama              Family',
#   'top_director': 'Phyllis Reynolds',
#   'top_actor': 'Blake Heron'},
#  {'title': 'From Up on Poppy Hill ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1002895,
#   'worldwide_gross_pay': 61487846,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 91,
#   'distributor': 'GKIDS',
#   'genre': 'Animation              Drama              Family              Romance',
#   'top_director': 'Tetsurô Sayama',
#   'top_actor': 'Sarah Bolger'},
#  {'title': 'March or Die ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 1000000,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 107,
#   'distributor': 'Columbia Pictures',
#   'genre': 'Adventure              Drama              Romance              War',
#   'top_director': 'David Zelag',
#   'top_actor': 'Gene Hackman'},
#  {'title': 'Campus Man ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 989528,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Matt Dorff',
#   'top_actor': 'John Dye'},
#  {'title': 'Million Dollar Mystery ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 989033,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'De Laurentiis Entertainment Group (DEG)',
#   'genre': 'Comedy              Mystery',
#   'top_director': 'Tim Metcalfe',
#   'top_actor': 'Eddie Deezen'},
#  {'title': "Meek's Cutoff ",
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 977772,
#   'worldwide_gross_pay': 1205257,
#   'budget': 2000000,
#   'lifetime_ranking': nan,
#   'running_time': 104,
#   'distributor': 'Oscilloscope',
#   'genre': 'Adventure              Drama              Thriller              Western',
#   'top_director': 'Jonathan Raymond',
#   'top_actor': 'Michelle Williams'},
#  {'title': 'The Tale of The Princess Kaguya ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 974913,
#   'worldwide_gross_pay': 24706166,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 137,
#   'distributor': 'GKIDS',
#   'genre': 'Adventure              Animation              Drama              Family              Fantasy',
#   'top_director': 'Isao Takahata',
#   'top_actor': 'Chloë Grace'},
#  {'title': 'Appointment with Death ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 960040,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 102,
#   'distributor': 'Cannon Film Distributors',
#   'genre': 'Crime              Drama              Mystery              Thriller',
#   'top_director': 'Agatha Christie',
#   'top_actor': 'Peter Ustinov'},
#  {'title': 'The Fighting Preacher ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 954641,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Purdie Distribution',
#   'genre': 'Comedy              Drama              History',
#   'top_director': 'T.C. Christensen',
#   'top_actor': 'David McConnell'},
#  {'title': 'Faces Places ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 953717,
#   'worldwide_gross_pay': 3996577,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'Cohen Media Group',
#   'genre': 'Documentary',
#   'top_director': 'Cast information',
#   'top_actor': 'Agnès Varda'},
#  {'title': 'The Ten Commandments ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 952820,
#   'worldwide_gross_pay': 1051907,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Rocky Mountain Pictures',
#   'genre': 'Animation              Family',
#   'top_director': 'John Stronach',
#   'top_actor': 'Ben Kingsley'},
#  {'title': 'More Than a Game ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 950675,
#   'worldwide_gross_pay': 960387,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 105,
#   'distributor': 'Lionsgate',
#   'genre': 'Biography              Documentary              Sport',
#   'top_director': 'Kristopher Belman',
#   'top_actor': 'LeBron James'},
#  {'title': 'Children of Heaven ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 933933,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Miramax',
#   'genre': 'Drama              Family              Sport',
#   'top_director': 'Majid Majidi',
#   'top_actor': 'Mohammad Amir'},
#  {'title': 'An Egg Rescue ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 926514,
#   'worldwide_gross_pay': 3349309,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 88,
#   'distributor': 'Pantelion Films',
#   'genre': 'Adventure              Animation              Comedy              Family              Fantasy',
#   'top_director': 'Rodolfo Riva',
#   'top_actor': 'Marcelo Barcelo'},
#  {'title': 'The Red Turtle ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 921974,
#   'worldwide_gross_pay': 6591789,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 80,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Animation              Family              Fantasy',
#   'top_director': 'Michael Dudok',
#   'top_actor': 'Emmanuel Garijo'},
#  {'title': 'Boruto: Naruto The Movie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 919651,
#   'worldwide_gross_pay': 38362448,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 95,
#   'distributor': 'Eleven Arts',
#   'genre': 'Action              Adventure              Animation              Comedy',
#   'top_director': 'Toshiyuki Tsuru',
#   'top_actor': 'Yûko Sanpei'},
#  {'title': 'Brain Donors ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 918239,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 80,
#   'distributor': 'Paramount Pictures',
#   'genre': 'Comedy',
#   'top_director': 'Pat Proft',
#   'top_actor': 'John Turturro'},
#  {'title': 'Lagaan: Once Upon a Time in India ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 909043,
#   'worldwide_gross_pay': 1724806,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 224,
#   'distributor': 'Set Pictures',
#   'genre': 'Drama              Musical              Sport',
#   'top_director': 'Ashutosh Gowariker',
#   'top_actor': 'Aamir Khan'},
#  {'title': 'The War Room ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 901668,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 96,
#   'distributor': 'October Films',
#   'genre': 'Documentary              History',
#   'top_director': 'D.A. Pennebaker',
#   'top_actor': 'James Carville'},
#  {'title': 'The Wildest Dream ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 898137,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 94,
#   'distributor': 'National Geographic Entertainment',
#   'genre': 'Biography              Documentary',
#   'top_director': 'Mark MacKenzie',
#   'top_actor': 'Conrad Anker'},
#  {'title': 'The Glass Menagerie ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 895904,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 134,
#   'distributor': 'Cineplex Odeon Films',
#   'genre': 'Drama',
#   'top_director': 'Tennessee Williams',
#   'top_actor': 'Joanne Woodward'},
#  {'title': 'Believe ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 890303,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 119,
#   'distributor': 'Freestyle Releasing',
#   'genre': 'Drama',
#   'top_director': 'Billy Dickson',
#   'top_actor': "Ryan O'Quinn"},
#  {'title': 'Saawariya ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 885574,
#   'worldwide_gross_pay': 18525631,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 142,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genre': 'Drama              Musical              Romance',
#   'top_director': 'Fyodor Dostoevsky',
#   'top_actor': 'Ranbir Kapoor'},
#  {'title': 'Princess Kaiulani ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 883887,
#   'worldwide_gross_pay': nan,
#   'budget': 9000000,
#   'lifetime_ranking': nan,
#   'running_time': 130,
#   'distributor': 'Roadside Attractions',
#   'genre': 'Biography              Drama              History              Romance',
#   'top_director': 'Marc Forby',
#   'top_actor': "Q'orianka Kilcher"},
#  {'title': 'Emma Smith: My Story ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 881787,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 98,
#   'distributor': 'Candlelight Media Group',
#   'genre': 'Biography              Drama              History',
#   'top_director': 'T.C. Christensen',
#   'top_actor': 'Patricia Place'},
#  {'title': 'Fast, Cheap & Out of Control ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 878960,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 80,
#   'distributor': 'Sony Pictures Classics',
#   'genre': 'Documentary',
#   'top_director': 'Errol Morris',
#   'top_actor': 'Dave Hoover'},
#  {'title': 'Duma ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 870067,
#   'worldwide_gross_pay': 994790,
#   'budget': 12000000,
#   'lifetime_ranking': nan,
#   'running_time': 100,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Drama              Family',
#   'top_director': 'Carol Cawthra',
#   'top_actor': 'Alex Michaeletos'},
#  {'title': 'Mirrormask ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 866999,
#   'worldwide_gross_pay': nan,
#   'budget': 4000000,
#   'lifetime_ranking': nan,
#   'running_time': 101,
#   'distributor': 'IDP Distribution',
#   'genre': 'Adventure              Fantasy',
#   'top_director': 'Neil Gaiman',
#   'top_actor': 'Stephanie Leonidas'},
#  {'title': 'Sarah Landon and the Paranormal Hour ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 858415,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 81,
#   'distributor': 'Freestyle Releasing',
#   'genre': 'Action              Adventure              Family              Fantasy              Horror              Mystery              Thriller',
#   'top_director': 'John Comrie',
#   'top_actor': 'Rissa Walters'},
#  {'title': 'Song of the Sea ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 857522,
#   'worldwide_gross_pay': 4190884,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'GKIDS',
#   'genre': 'Adventure              Animation              Drama              Family              Fantasy',
#   'top_director': 'Will Collins',
#   'top_actor': 'David Rawle'},
#  {'title': 'Sharkwater ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 850920,
#   'worldwide_gross_pay': 1658393,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 89,
#   'distributor': 'Freestyle Releasing',
#   'genre': 'Documentary',
#   'top_director': 'Rob Stewart',
#   'top_actor': 'Rob Stewart'},
#  {'title': 'Scoob! ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 850000,
#   'worldwide_gross_pay': 25750000,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 93,
#   'distributor': 'Warner Bros.',
#   'genre': 'Adventure              Animation              Comedy              Crime              Family              Fantasy              Mystery              Sci-Fi',
#   'top_director': 'Adam Sztykiel',
#   'top_actor': 'Will Forte'},
#  {'title': 'Guadalupe: El Milagro Y El Mensaje ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 848139,
#   'worldwide_gross_pay': 1499149,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 90,
#   'distributor': 'Slowhand Cinema Releasing',
#   'genre': 'Drama              Family              Fantasy              Mystery',
#   'top_director': 'Tessie Gutierrez',
#   'top_actor': 'José Carlos'},
#  {'title': 'Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean ',
#   'MPAA_rate': 'PG',
#   'domestic_gross_pay': 840958,
#   'worldwide_gross_pay': nan,
#   'budget': nan,
#   'lifetime_ranking': nan,
#   'running_time': 109,
#   'distributor': 'Cinecom Pictures',
#   'genre': 'Comedy              Drama',
#   'top_director': 'Ed Graczyk',
#   'top_actor': 'Cher SissySee'}]

# %%
import pandas as pd
movies_page_info = pd.DataFrame(movies_page_info_dict)
movies_page_info.set_index('title',inplace = True)
genre_page_info = movies_page_info.genre.str.split(n = 3, expand=True)
new_movies_page_info = movies_page_info.join(genre_page_info, on='title', how='outer', sort=False)
new_movies_page_info.rename(columns={0:'first_genre'}, inplace=True)
new_movies_page_info.rename(columns={1:'second_genre'}, inplace=True)
new_movies_page_info.rename(columns={2:'third_genre'}, inplace=True)
new_movies_page_info.rename(columns={3:'fourth_genre'}, inplace=True)
new_movies_page_info
# Out:
#                                                   MPAA_rate  \
# title
# See Spot Run                                             PG
# Teen Wolf                                                PG
# The Second Best Exotic Marigold Hotel                    PG
# Tron                                                     PG
# The Sandlot                                              PG
# ...                                                     ...
# Song of the Sea                                          PG
# Sharkwater                                               PG
# Scoob!                                                   PG
# Guadalupe: El Milagro Y El Mensaje                       PG
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean         PG
#
#                                                    domestic_gross_pay  \
# title
# See Spot Run                                                 33357476
# Teen Wolf                                                    33086611
# The Second Best Exotic Marigold Hotel                        33078266
# Tron                                                         33000000
# The Sandlot                                                  32950136
# ...                                                               ...
# Song of the Sea                                                857522
# Sharkwater                                                     850920
# Scoob!                                                         850000
# Guadalupe: El Milagro Y El Mensaje                             848139
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean               840958
#
#                                                    worldwide_gross_pay  \
# title
# See Spot Run                                                43057552.0
# Teen Wolf                                                          NaN
# The Second Best Exotic Marigold Hotel                       85978292.0
# Tron                                                        33000525.0
# The Sandlot                                                 34348443.0
# ...                                                                ...
# Song of the Sea                                              4190884.0
# Sharkwater                                                   1658393.0
# Scoob!                                                      25750000.0
# Guadalupe: El Milagro Y El Mensaje                           1499149.0
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean                   NaN
#
#                                                        budget  \
# title
# See Spot Run                                       35000000.0
# Teen Wolf                                                 NaN
# The Second Best Exotic Marigold Hotel              10000000.0
# Tron                                               17000000.0
# The Sandlot                                               NaN
# ...                                                       ...
# Song of the Sea                                           NaN
# Sharkwater                                                NaN
# Scoob!                                                    NaN
# Guadalupe: El Milagro Y El Mensaje                        NaN
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean          NaN
#
#                                                    lifetime_ranking  \
# title
# See Spot Run                                                    NaN
# Teen Wolf                                                       NaN
# The Second Best Exotic Marigold Hotel                           NaN
# Tron                                                            NaN
# The Sandlot                                                     NaN
# ...                                                             ...
# Song of the Sea                                                 NaN
# Sharkwater                                                      NaN
# Scoob!                                                          NaN
# Guadalupe: El Milagro Y El Mensaje                              NaN
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean                NaN
#
#                                                    running_time  \
# title
# See Spot Run                                               94.0
# Teen Wolf                                                  91.0
# The Second Best Exotic Marigold Hotel                     122.0
# Tron                                                       96.0
# The Sandlot                                               101.0
# ...                                                         ...
# Song of the Sea                                            93.0
# Sharkwater                                                 89.0
# Scoob!                                                     93.0
# Guadalupe: El Milagro Y El Mensaje                         90.0
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean          109.0
#
#                                                                            distributor  \
# title
# See Spot Run                                                              Warner Bros.
# Teen Wolf                                               Atlantic Releasing Corporation
# The Second Best Exotic Marigold Hotel                         Fox Searchlight Pictures
# Tron                                               Walt Disney Studios Motion Pictures
# The Sandlot                                                      Twentieth Century Fox
# ...                                                                                ...
# Song of the Sea                                                                  GKIDS
# Sharkwater                                                         Freestyle Releasing
# Scoob!                                                                    Warner Bros.
# Guadalupe: El Milagro Y El Mensaje                           Slowhand Cinema Releasing
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean                      Cinecom Pictures
#
#                                                                                                genre  \
# title
# See Spot Run                                       Action              Comedy              Crime ...
# Teen Wolf                                           Comedy              Fantasy              Romance
# The Second Best Exotic Marigold Hotel                 Comedy              Drama              Romance
# Tron                                               Action              Adventure              Sci-Fi
# The Sandlot                                        Comedy              Drama              Family ...
# ...                                                                                              ...
# Song of the Sea                                    Adventure              Animation              ...
# Sharkwater                                                                               Documentary
# Scoob!                                             Adventure              Animation              ...
# Guadalupe: El Milagro Y El Mensaje                 Drama              Family              Fantasy...
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean                           Comedy              Drama
#
#                                                        top_director  \
# title
# See Spot Run                                           George Gallo
# Teen Wolf                                                 Jeph Loeb
# The Second Best Exotic Marigold Hotel                     Ol Parker
# Tron                                               Steven Lisberger
# The Sandlot                                            David Mickey
# ...                                                             ...
# Song of the Sea                                        Will Collins
# Sharkwater                                              Rob Stewart
# Scoob!                                                Adam Sztykiel
# Guadalupe: El Milagro Y El Mensaje                 Tessie Gutierrez
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean         Ed Graczyk
#
#                                                         top_actor  \
# title
# See Spot Run                                       David Arquette
# Teen Wolf                                              Michael J.
# The Second Best Exotic Marigold Hotel                  Judi Dench
# Tron                                                 Jeff Bridges
# The Sandlot                                             Tom Guiry
# ...                                                           ...
# Song of the Sea                                       David Rawle
# Sharkwater                                            Rob Stewart
# Scoob!                                                 Will Forte
# Guadalupe: El Milagro Y El Mensaje                    José Carlos
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean    Cher SissySee
#
#                                                    first_genre second_genre  \
# title
# See Spot Run                                            Action       Comedy
# Teen Wolf                                               Comedy      Fantasy
# The Second Best Exotic Marigold Hotel                   Comedy        Drama
# Tron                                                    Action    Adventure
# The Sandlot                                             Comedy        Drama
# ...                                                        ...          ...
# Song of the Sea                                      Adventure    Animation
# Sharkwater                                         Documentary         None
# Scoob!                                               Adventure    Animation
# Guadalupe: El Milagro Y El Mensaje                       Drama       Family
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean        Comedy        Drama
#
#                                                   third_genre  \
# title
# See Spot Run                                            Crime
# Teen Wolf                                             Romance
# The Second Best Exotic Marigold Hotel                 Romance
# Tron                                                   Sci-Fi
# The Sandlot                                            Family
# ...                                                       ...
# Song of the Sea                                         Drama
# Sharkwater                                               None
# Scoob!                                                 Comedy
# Guadalupe: El Milagro Y El Mensaje                    Fantasy
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean         None
#
#                                                                                         fourth_genre
# title
# See Spot Run                                                                                  Family
# Teen Wolf                                                                                       None
# The Second Best Exotic Marigold Hotel                                                           None
# Tron                                                                                            None
# The Sandlot                                                                                    Sport
# ...                                                                                              ...
# Song of the Sea                                                          Family              Fantasy
# Sharkwater                                                                                      None
# Scoob!                                             Crime              Family              Fantasy...
# Guadalupe: El Milagro Y El Mensaje                                                           Mystery
# Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean                                                None
#
# [996 rows x 14 columns]

# %%
new_movies_page_info.to_csv('movie_data.csv')

# %%
copy_movies_page_info = new_movies_page_info
copy_movies_page_info
# Out:
#                                        MPAA_rate  domestic_gross_pay  \
# title
# See Spot Run                                  PG            33357476
# Teen Wolf                                     PG            33086611
# The Second Best Exotic Marigold Hotel         PG            33078266
# Tron                                          PG            33000000
# The Sandlot                                   PG            32950136
# ...                                          ...                 ...
# A Cry in the Wild                             PG             1494969
# Evelyn                                        PG             1487645
# My Mother's Castle                            PG             1477071
# Clockwise                                     PG             1476356
# Ernest Rides Again                            PG             1450029
#
#                                         worldwide_gross_pay      budget  \
# title
# See Spot Run                                     43057552.0  35000000.0
# Teen Wolf                                               NaN         NaN
# The Second Best Exotic Marigold Hotel            85978292.0  10000000.0
# Tron                                             33000525.0  17000000.0
# The Sandlot                                      34348443.0         NaN
# ...                                                     ...         ...
# A Cry in the Wild                                       NaN         NaN
# Evelyn                                            4186916.0         NaN
# My Mother's Castle                                      NaN         NaN
# Clockwise                                               NaN         NaN
# Ernest Rides Again                                      NaN         NaN
#
#                                         lifetime_ranking  running_time  \
# title
# See Spot Run                                         NaN          94.0
# Teen Wolf                                            NaN          91.0
# The Second Best Exotic Marigold Hotel                NaN         122.0
# Tron                                                 NaN          96.0
# The Sandlot                                          NaN         101.0
# ...                                                  ...           ...
# A Cry in the Wild                                    NaN          82.0
# Evelyn                                               NaN          94.0
# My Mother's Castle                                   NaN          98.0
# Clockwise                                            NaN          96.0
# Ernest Rides Again                                   NaN          96.0
#
#                                                                 distributor  \
# title
# See Spot Run                                                   Warner Bros.
# Teen Wolf                                    Atlantic Releasing Corporation
# The Second Best Exotic Marigold Hotel              Fox Searchlight Pictures
# Tron                                    Walt Disney Studios Motion Pictures
# The Sandlot                                           Twentieth Century Fox
# ...                                                                     ...
# A Cry in the Wild                                         Concorde Pictures
# Evelyn                                            Metro-Goldwyn-Mayer (MGM)
# My Mother's Castle                                           Orion Classics
# Clockwise                                                Universal Pictures
# Ernest Rides Again                                 Emshell Production Group
#
#                                                                                     genre  \
# title
# See Spot Run                            Action              Comedy              Crime ...
# Teen Wolf                                Comedy              Fantasy              Romance
# The Second Best Exotic Marigold Hotel      Comedy              Drama              Romance
# Tron                                    Action              Adventure              Sci-Fi
# The Sandlot                             Comedy              Drama              Family ...
# ...                                                                                   ...
# A Cry in the Wild                       Action              Adventure              Thr...
# Evelyn                                                                              Drama
# My Mother's Castle                      Adventure              Biography              ...
# Clockwise                                                                          Comedy
# Ernest Rides Again                                             Comedy              Family
#
#                                             top_director       top_actor  \
# title
# See Spot Run                                George Gallo  David Arquette
# Teen Wolf                                      Jeph Loeb      Michael J.
# The Second Best Exotic Marigold Hotel          Ol Parker      Judi Dench
# Tron                                    Steven Lisberger    Jeff Bridges
# The Sandlot                                 David Mickey       Tom Guiry
# ...                                                  ...             ...
# A Cry in the Wild                           Gary Paulsen   Jared Rushton
# Evelyn                                       Paul Pender  Pierce Brosnan
# My Mother's Castle                         Marcel Pagnol   Genre keyword
# Clockwise                                  Michael Frayn     John Cleese
# Ernest Rides Again                               John R.   Genre keyword
#
#                                        first_genre second_genre third_genre  \
# title
# See Spot Run                                Action       Comedy       Crime
# Teen Wolf                                   Comedy      Fantasy     Romance
# The Second Best Exotic Marigold Hotel       Comedy        Drama     Romance
# Tron                                        Action    Adventure      Sci-Fi
# The Sandlot                                 Comedy        Drama      Family
# ...                                            ...          ...         ...
# A Cry in the Wild                           Action    Adventure    Thriller
# Evelyn                                       Drama         None        None
# My Mother's Castle                       Adventure    Biography      Comedy
# Clockwise                                   Comedy         None        None
# Ernest Rides Again                          Comedy       Family        None
#
#                                                       fourth_genre
# title
# See Spot Run                                                Family
# Teen Wolf                                                     None
# The Second Best Exotic Marigold Hotel                         None
# Tron                                                          None
# The Sandlot                                                  Sport
# ...                                                            ...
# A Cry in the Wild                                             None
# Evelyn                                                        None
# My Mother's Castle                      Drama              Romance
# Clockwise                                                     None
# Ernest Rides Again                                            None
#
# [500 rows x 14 columns]

# %%
copy_movies_page_info.info()
copy_movies_page_info.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, See Spot Run  to Ernest Rides Again
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MPAA_rate            500 non-null    object
#  1   domestic_gross_pay   500 non-null    int64
#  2   worldwide_gross_pay  181 non-null    float64
#  3   budget               98 non-null     float64
#  4   lifetime_ranking     0 non-null      float64
#  5   running_time         491 non-null    float64
#  6   distributor          500 non-null    object
#  7   genre                500 non-null    object
#  8   top_director         500 non-null    object
#  9   top_actor            498 non-null    object
#  10  first_genre          500 non-null    object
#  11  second_genre         445 non-null    object
#  12  third_genre          305 non-null    object
#  13  fourth_genre         135 non-null    object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 58.6+ KB
# Index(['MPAA_rate', 'domestic_gross_pay', 'worldwide_gross_pay', 'budget',
#        'lifetime_ranking', 'running_time', 'distributor', 'genre',
#        'top_director', 'top_actor', 'first_genre', 'second_genre',
#        'third_genre', 'fourth_genre'],
#       dtype='object')

# %%
copy_movies_page_info = copy_movies_page_info[~copy_movies_page_info.index.duplicated(keep='first')]
copy_movies_page_info['worldwide_gross_pay'] = copy_movies_page_info['worldwide_gross_pay'].fillna(copy_movies_page_info['domestic_gross_pay'])
copy_movies_page_info.info()
copy_movies_page_info.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, See Spot Run  to Ernest Rides Again
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MPAA_rate            500 non-null    object
#  1   domestic_gross_pay   500 non-null    int64
#  2   worldwide_gross_pay  500 non-null    float64
#  3   budget               98 non-null     float64
#  4   lifetime_ranking     0 non-null      float64
#  5   running_time         491 non-null    float64
#  6   distributor          500 non-null    object
#  7   genre                500 non-null    object
#  8   top_director         500 non-null    object
#  9   top_actor            498 non-null    object
#  10  first_genre          500 non-null    object
#  11  second_genre         445 non-null    object
#  12  third_genre          305 non-null    object
#  13  fourth_genre         135 non-null    object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 58.6+ KB
# Index(['MPAA_rate', 'domestic_gross_pay', 'worldwide_gross_pay', 'budget',
#        'lifetime_ranking', 'running_time', 'distributor', 'genre',
#        'top_director', 'top_actor', 'first_genre', 'second_genre',
#        'third_genre', 'fourth_genre'],
#       dtype='object')

# %%
#make other cells to make data more readable
dist_counts = copy_movies_page_info.distributor.value_counts()
other_dist = list(dist_counts[dist_counts <=13].index)
copy_movies_page_info['distributor'] = copy_movies_page_info['distributor'].replace(other_dist,'Other_Dist')
copy_movies_page_info.distributor.value_counts()
# Out:
# Other_Dist                             174
# Warner Bros.                            69
# Universal Pictures                      54
# Walt Disney Studios Motion Pictures     42
# Twentieth Century Fox                   39
# Paramount Pictures                      37
# Metro-Goldwyn-Mayer (MGM)               34
# Columbia Pictures                       21
# TriStar Pictures                        16
# Sony Pictures Classics                  14
# Name: distributor, dtype: int64

# %%
#make other cells to make data more readable
actor_counts = copy_movies_page_info.top_actor.value_counts()
other_actor = list(actor_counts[actor_counts <=2].index)
copy_movies_page_info['top_actor'] = copy_movies_page_info['top_actor'].replace(other_actor,'Other_Actor').replace('Genre keyword','Other_Actor').replace(np.nan,'Other_Actor')
copy_movies_page_info.top_actor.value_counts()
# Out:
# Other_Actor        436
# Woody Allen          7
# Chevy Chase          5
# Michael Caine        4
# Burt Reynolds        4
# Peter Sellers        4
# Jeff Bridges         4
# Tom Berenger         3
# Hilary Duff          3
# Brendan Fraser       3
# Christina Ricci      3
# Robert De            3
# Rick Moranis         3
# John Cusack          3
# Anthony Hopkins      3
# Gene Hackman         3
# Clint Eastwood       3
# Tom Hanks            3
# Mel Gibson           3
# Name: top_actor, dtype: int64

# %%
first_genre_counts = copy_movies_page_info.first_genre.value_counts()
other_first_genre = list(first_genre_counts[first_genre_counts <=5].index)
copy_movies_page_info['first_genre'] = copy_movies_page_info['first_genre'].replace(other_first_genre,'Other_First_Genre')
copy_movies_page_info.first_genre.value_counts()
# Out:
# Comedy               192
# Drama                 90
# Adventure             80
# Action                71
# Biography             31
# Other_First_Genre     20
# Documentary           16
# Name: first_genre, dtype: int64

# %%
second_genre_counts = copy_movies_page_info.second_genre.value_counts()
other_second_genre = list(second_genre_counts[second_genre_counts <=10].index)
copy_movies_page_info['second_genre'] = copy_movies_page_info['second_genre'].replace(other_second_genre,'Other_Second_Genre')
copy_movies_page_info.second_genre.value_counts()
# Out:
# Drama                 118
# Comedy                 49
# Family                 49
# Adventure              45
# Romance                40
# Other_Second_Genre     36
# Crime                  27
# Animation              20
# Fantasy                19
# Music                  19
# Mystery                12
# Sci-Fi                 11
# Name: second_genre, dtype: int64

# %%
third_genre_counts = copy_movies_page_info.third_genre.value_counts()
other_third_genre = list(third_genre_counts[third_genre_counts <=8].index)
copy_movies_page_info['third_genre'] = copy_movies_page_info['third_genre'].replace(other_third_genre,'Other_Third_Genre')
copy_movies_page_info.third_genre.value_counts()
copy_movies_page_info
# Out:
#                                        MPAA_rate  domestic_gross_pay  \
# title
# See Spot Run                                  PG            33357476
# Teen Wolf                                     PG            33086611
# The Second Best Exotic Marigold Hotel         PG            33078266
# Tron                                          PG            33000000
# The Sandlot                                   PG            32950136
# ...                                          ...                 ...
# A Cry in the Wild                             PG             1494969
# Evelyn                                        PG             1487645
# My Mother's Castle                            PG             1477071
# Clockwise                                     PG             1476356
# Ernest Rides Again                            PG             1450029
#
#                                         worldwide_gross_pay      budget  \
# title
# See Spot Run                                     43057552.0  35000000.0
# Teen Wolf                                        33086611.0         NaN
# The Second Best Exotic Marigold Hotel            85978292.0  10000000.0
# Tron                                             33000525.0  17000000.0
# The Sandlot                                      34348443.0         NaN
# ...                                                     ...         ...
# A Cry in the Wild                                 1494969.0         NaN
# Evelyn                                            4186916.0         NaN
# My Mother's Castle                                1477071.0         NaN
# Clockwise                                         1476356.0         NaN
# Ernest Rides Again                                1450029.0         NaN
#
#                                         lifetime_ranking  running_time  \
# title
# See Spot Run                                         NaN          94.0
# Teen Wolf                                            NaN          91.0
# The Second Best Exotic Marigold Hotel                NaN         122.0
# Tron                                                 NaN          96.0
# The Sandlot                                          NaN         101.0
# ...                                                  ...           ...
# A Cry in the Wild                                    NaN          82.0
# Evelyn                                               NaN          94.0
# My Mother's Castle                                   NaN          98.0
# Clockwise                                            NaN          96.0
# Ernest Rides Again                                   NaN          96.0
#
#                                                                 distributor  \
# title
# See Spot Run                                                   Warner Bros.
# Teen Wolf                                                        Other_Dist
# The Second Best Exotic Marigold Hotel                            Other_Dist
# Tron                                    Walt Disney Studios Motion Pictures
# The Sandlot                                           Twentieth Century Fox
# ...                                                                     ...
# A Cry in the Wild                                                Other_Dist
# Evelyn                                            Metro-Goldwyn-Mayer (MGM)
# My Mother's Castle                                               Other_Dist
# Clockwise                                                Universal Pictures
# Ernest Rides Again                                               Other_Dist
#
#                                                                                     genre  \
# title
# See Spot Run                            Action              Comedy              Crime ...
# Teen Wolf                                Comedy              Fantasy              Romance
# The Second Best Exotic Marigold Hotel      Comedy              Drama              Romance
# Tron                                    Action              Adventure              Sci-Fi
# The Sandlot                             Comedy              Drama              Family ...
# ...                                                                                   ...
# A Cry in the Wild                       Action              Adventure              Thr...
# Evelyn                                                                              Drama
# My Mother's Castle                      Adventure              Biography              ...
# Clockwise                                                                          Comedy
# Ernest Rides Again                                             Comedy              Family
#
#                                             top_director     top_actor  \
# title
# See Spot Run                                George Gallo   Other_Actor
# Teen Wolf                                      Jeph Loeb   Other_Actor
# The Second Best Exotic Marigold Hotel          Ol Parker   Other_Actor
# Tron                                    Steven Lisberger  Jeff Bridges
# The Sandlot                                 David Mickey   Other_Actor
# ...                                                  ...           ...
# A Cry in the Wild                           Gary Paulsen   Other_Actor
# Evelyn                                       Paul Pender   Other_Actor
# My Mother's Castle                         Marcel Pagnol   Other_Actor
# Clockwise                                  Michael Frayn   Other_Actor
# Ernest Rides Again                               John R.   Other_Actor
#
#                                        first_genre        second_genre  \
# title
# See Spot Run                                Action              Comedy
# Teen Wolf                                   Comedy             Fantasy
# The Second Best Exotic Marigold Hotel       Comedy               Drama
# Tron                                        Action           Adventure
# The Sandlot                                 Comedy               Drama
# ...                                            ...                 ...
# A Cry in the Wild                           Action           Adventure
# Evelyn                                       Drama                None
# My Mother's Castle                       Adventure  Other_Second_Genre
# Clockwise                                   Comedy                None
# Ernest Rides Again                          Comedy              Family
#
#                                        third_genre                fourth_genre
# title
# See Spot Run                                 Crime                      Family
# Teen Wolf                                  Romance                        None
# The Second Best Exotic Marigold Hotel      Romance                        None
# Tron                                        Sci-Fi                        None
# The Sandlot                                 Family                       Sport
# ...                                            ...                         ...
# A Cry in the Wild                         Thriller                        None
# Evelyn                                        None                        None
# My Mother's Castle                          Comedy  Drama              Romance
# Clockwise                                     None                        None
# Ernest Rides Again                            None                        None
#
# [500 rows x 14 columns]

# %%
import seaborn as sns
sns.pairplot(copy_movies_page_info, height = 1.5)

# %%
copy_movies_dummies_info = pd.get_dummies(copy_movies_page_info, columns = ['distributor','first_genre'], drop_first = False)
copy_movies_dummies_info.columns

# %%
from sklearn.model_selection import train_test_split
X, X_test,y, y_test = train_test_split(copy_movies_dummies_info[[ 'budget',
       'running_time',
       'distributor_Lionsgate', 'distributor_Metro-Goldwyn-Mayer (MGM)',
       'distributor_Miramax', 'distributor_New Line Cinema',
       'distributor_Other_Dist', 'distributor_Paramount Pictures',
       'distributor_Revolution Studios', 'distributor_Screen Gems',
       'distributor_Sony Pictures Entertainment (SPE)',
       'distributor_Twentieth Century Fox', 'distributor_Universal Pictures',
       'distributor_Walt Disney Studios Motion Pictures',
       'distributor_Warner Bros.', 'first_genre_Adventure',
       'first_genre_Biography', 'first_genre_Comedy', 'first_genre_Crime',
       'first_genre_Drama', 'first_genre_Horror', 'first_genre_Action']],copy_movies_dummies_info['domestic_gross_pay'], test_size=0.2,random_state=40)
X.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4x/xbyghx1j10n7wzncgwg27zfm0000gn/T/ipykernel_61637/137415724.py in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X, X_test,y, y_test = train_test_split(copy_movies_dummies_info[[ 'budget',
#       3        'running_time',
#       4        'distributor_Lionsgate', 'distributor_Metro-Goldwyn-Mayer (MGM)',
#       5        'distributor_Miramax', 'distributor_New Line Cinema',
#
# NameError: name 'copy_movies_dummies_info' is not defined

# %%
X['running_time'] = X['running_time'].fillna(X['running_time'].median())
X['budget'] = X['budget'].fillna(X['budget'].median())
X_test['running_time'] = X_test['running_time'].fillna(X['running_time'].median())
X_test['budget'] = X_test['budget'].fillna(X['budget'].median())
X['budget2'] = X['budget']**2
X_test['budget2'] = X_test['budget']**2
X.info()

# %%
features, target = ['budget',
     'running_time',
       'distributor_Lionsgate', 'distributor_Metro-Goldwyn-Mayer (MGM)',
       'distributor_Miramax', 'distributor_New Line Cinema',
       'distributor_Other_Dist', 'distributor_Paramount Pictures',
       'distributor_Revolution Studios', 'distributor_Screen Gems',
       'distributor_Sony Pictures Entertainment (SPE)',
       'distributor_Twentieth Century Fox', 'distributor_Universal Pictures',
       'distributor_Walt Disney Studios Motion Pictures',
       'distributor_Warner Bros.', 'first_genre_Adventure',
       'first_genre_Biography', 'first_genre_Comedy', 'first_genre_Crime',
       'first_genre_Drama', 'first_genre_Fantasy', 'first_genre_Horror',
       'first_genre_Mystery', 'first_genre_Romance', 'first_genre_Sci-Fi',
       'first_genre_Thriller', 'budget2', 'first_genre_Action'],['domestic_gross_pay']
lr_model = LinearRegression()
lr_model.fit(X,y)

# %%
lr_model.score(X,y)

# %%
lr_model.score(X_test,y_test)

# %%
copy_movies_dummies_info.corr()

# %%
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LinearRegression, LassoCV, RidgeCV, ElasticNetCV

from sklearn.model_selection import (cross_val_score, train_test_split, 
                                     KFold, GridSearchCV)
X_val.info()

# %%
#Standardize data
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
std.fit(X.values)
X_std = std.transform(X.values)
X_std_test = std.transform(X_test.values)

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=40)
lin_reg_est = LinearRegression()
scores_train = cross_val_score(lin_reg_est,X,y,cv=kfold)
np.mean(scores)
scores_test = cross_val_score(lin_reg_est,X_test,y_test,cv=kfold)
scores_train
np.mean(scores_train)

# %%
scores_test
np.mean(scores_test)

# %%
#Find LASSO model
import numpy as np
alphavec = 10**np.linspace(-2,2,200)
lasso_model = LassoCV(alphas = alphavec, cv=kfold)
lasso_model.fit(X_std,y)
lasso_model.alpha_
lasso_model.score(X_std,y)

# %%
list(zip(X.columns,lasso_model.coef_))

# %%
test_set_pred = lasso_model.predict(X_std_test)

# %%
#Find Ridge
alphavec = 10**np.linspace(-2,2,200)
ridge_model = RidgeCV(alphas = alphavec, cv=kfold)
ridge_model.fit(X_std_train, y_train)
ridge_model.alpha_
ridge_model.score(X_std_train,y_train)

# %%
list(zip(X_train.columns,ridge_model.coef_))
